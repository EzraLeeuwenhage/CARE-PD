# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
from pathlib import Path

zip_path = Path("/content/drive/MyDrive/CARE-PD/code.zip")
target_dir = Path("/content/drive/MyDrive/CARE-PD/thesis")

target_dir.mkdir(parents=True, exist_ok=True)

if not zip_path.exists():
    raise FileNotFoundError(f"Could not find '{zip_path}'.")

print(f"Unpacking '{zip_path}' into '{target_dir}'...")
shutil.unpack_archive(zip_path, extract_dir=target_dir)

print("Unpacking complete!")
# Out:
# Unpacking '/content/drive/MyDrive/CARE-PD/code.zip' into '/content/drive/MyDrive/CARE-PD/thesis'...
# Unpacking complete!

# %%
# !pip install -q uv

import os
os.chdir("/content/drive/MyDrive/CARE-PD")

# !uv pip compile pyproject.toml -o /tmp/reqs.txt
# !uv pip install --system -r /tmp/reqs.txt
# Out:
# Resolved 107 packages in 229ms
# # This file was autogenerated by uv via the following command:
# #    uv pip compile pyproject.toml -o /tmp/reqs.txt
# aiohappyeyeballs==2.7.1
#     # via aiohttp
# aiohttp==3.14.3
#     # via
#     #   fsspec
#     #   torch-geometric
# aiosignal==1.4.0
#     # via aiohttp
# alembic==1.19.1
#     # via optuna
# annotated-types==0.8.0
#     # via pydantic
# anyio==4.14.2
#     # via httpx
# attrs==26.1.0
#     # via aiohttp
# beautifulsoup4==4.15.0
#     # via
#     #   gdown
#     #   google
# certifi==2026.7.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
#     #   sentry-sdk
# charset-normalizer==3.5.1
#     # via requests
# chumpy==0.70
#     # via care-pd (pyproject.toml)
# click==8.5.0
#     # via
#     #   huggingface-hub
#     #   wandb
# colorlog==6.12.0
#     # via optuna
# contourpy==1.3.3
#     # via matplotlib
# cuda-bindings==13.3.1
#     # via torch
# cuda-pathfinder==1.8.0
#     # via cuda-bindings
# cuda-toolkit==13.0.2
#     # via torch
# cycler==0.12.1
#     # via matplotlib
# einops==0.8.1
#     # via care-pd (pyproject.toml)
# filelock==3.32.4
#     # via
#     #   gdown
#     #   huggingface-hub
#     #   torch
# fonttools==4.63.0
#     # via matplotlib
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.7.0
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   pytorch-lightning
#     #   torch
#     #   torch-geometric
# gdown==6.1.0
#     # via care-pd (pyproject.toml)
# google==3.0.0
#     # via care-pd (pyproject.toml)
# greenlet==3.1.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   sqlalchemy
# h11==0.16.0
#     # via httpcore
# hf-xet==1.6.0
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via huggingface-hub
# huggingface-hub==1.29.0
#     # via timm
# idna==3.19
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# imageio==2.31.5
#     # via care-pd (pyproject.toml)
# jinja2==3.1.6
#     # via
#     #   torch
#     #   torch-geometric
# joblib==1.4.2
#     # via
#     #   care-pd (pyproject.toml)
#     #   scikit-learn
# kiwisolver==1.5.0
#     # via matplotlib
# lightning==2.6.5
#     # via care-pd (pyproject.toml)
# lightning-utilities==0.15.3
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   torchmetrics
# mako==1.4.1
#     # via alembic
# markupsafe==3.0.3
#     # via
#     #   jinja2
#     #   mako
# matplotlib==3.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# mpmath==1.3.0
#     # via sympy
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# networkx==3.6.1
#     # via torch
# numpy==1.26.4
#     # via
#     #   care-pd (pyproject.toml)
#     #   contourpy
#     #   imageio
#     #   matplotlib
#     #   numpyencoder
#     #   optuna
#     #   pandas
#     #   scikit-learn
#     #   scipy
#     #   seaborn
#     #   smplx
#     #   torch-geometric
#     #   torchmetrics
#     #   torchvision
#     #   trimesh
# numpyencoder==0.3.0
#     # via care-pd (pyproject.toml)
# nvidia-cublas==13.1.1.3
#     # via
#     #   nvidia-cudnn-cu13
#     #   nvidia-cusolver
#     #   torch
# nvidia-cuda-cupti==13.0.85
#     # via cuda-toolkit
# nvidia-cuda-nvrtc==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cublas
# nvidia-cuda-runtime==13.0.96
#     # via cuda-toolkit
# nvidia-cudnn-cu13==9.20.0.48
#     # via torch
# nvidia-cufft==12.0.0.61
#     # via cuda-toolkit
# nvidia-cufile==1.15.1.6
#     # via cuda-toolkit
# nvidia-curand==10.4.0.35
#     # via cuda-toolkit
# nvidia-cusolver==12.0.4.66
#     # via cuda-toolkit
# nvidia-cusparse==12.6.3.3
#     # via
#     #   cuda-toolkit
#     #   nvidia-cusolver
# nvidia-cusparselt-cu13==0.8.1
#     # via torch
# nvidia-nccl-cu13==2.29.7
#     # via torch
# nvidia-nvjitlink==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cufft
#     #   nvidia-cusolver
#     #   nvidia-cusparse
# nvidia-nvshmem-cu13==3.4.5
#     # via torch
# nvidia-nvtx==13.0.85
#     # via cuda-toolkit
# opentelemetry-api==1.44.0
#     # via wandb
# optuna==4.2.1
#     # via care-pd (pyproject.toml)
# packaging==26.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   matplotlib
#     #   optuna
#     #   pytorch-lightning
#     #   torchmetrics
#     #   wandb
# pandas==2.2.3
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# pillow==12.3.0
#     # via
#     #   imageio
#     #   matplotlib
#     #   torchvision
# platformdirs==4.11.5
#     # via wandb
# propcache==0.5.2
#     # via
#     #   aiohttp
#     #   yarl
# protobuf==7.36.0
#     # via wandb
# psutil==7.2.2
#     # via torch-geometric
# pydantic==2.13.4
#     # via wandb
# pydantic-core==2.46.4
#     # via pydantic
# pyparsing==3.3.2
#     # via
#     #   matplotlib
#     #   torch-geometric
# pysocks==1.7.1
#     # via requests
# python-dateutil==2.9.0.post0
#     # via
#     #   matplotlib
#     #   pandas
# pytorch-lightning==2.6.5
#     # via lightning
# pytz==2026.3.post1
#     # via pandas
# pyyaml==6.0.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   timm
#     #   wandb
# requests==2.34.2
#     # via
#     #   gdown
#     #   torch-geometric
#     #   wandb
# safetensors==0.8.0
#     # via timm
# scikit-learn==1.6.1
#     # via care-pd (pyproject.toml)
# scipy==1.17.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   chumpy
#     #   scikit-learn
# seaborn==0.13.2
#     # via care-pd (pyproject.toml)
# sentry-sdk==2.68.1
#     # via wandb
# setuptools==75.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   torch
# six==1.17.0
#     # via
#     #   chumpy
#     #   python-dateutil
# smplx==0.1.28
#     # via care-pd (pyproject.toml)
# soupsieve==2.9.2
#     # via beautifulsoup4
# sqlalchemy==2.0.52
#     # via
#     #   alembic
#     #   optuna
# sympy==1.14.0
#     # via torch
# threadpoolctl==3.6.0
#     # via scikit-learn
# timm==1.0.15
#     # via care-pd (pyproject.toml)
# torch==2.12.1
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   smplx
#     #   timm
#     #   torch-dct
#     #   torchmetrics
#     #   torchvision
# torch-dct==0.1.6
#     # via care-pd (pyproject.toml)
# torch-geometric==2.8.0.post1
#     # via care-pd (pyproject.toml)
# torchmetrics==1.9.0
#     # via
#     #   lightning
#     #   pytorch-lightning
# torchvision==0.27.1
#     # via timm
# tqdm==4.66.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   gdown
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   torch-geometric
# trimesh==4.6.8
#     # via care-pd (pyproject.toml)
# triton==3.7.1
#     # via torch
# typing-extensions==4.16.0
#     # via
#     #   alembic
#     #   beautifulsoup4
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   opentelemetry-api
#     #   pydantic
#     #   pydantic-core
#     #   pytorch-lightning
#     #   sqlalchemy
#     #   torch
#     #   typing-inspection
#     #   wandb
# typing-inspection==0.4.4
#     # via pydantic
# tzdata==2026.3
#     # via pandas
# urllib3==2.7.0
#     # via
#     #   requests
#     #   sentry-sdk
# wandb==0.29.0
#     # via care-pd (pyproject.toml)
# xxhash==4.0.1
#     # via
#     #   torch-geometric
#     #   wandb
# yarl==1.24.5
#     # via aiohttp
# Using Python 3.13.15 environment at: /usr
# Checked 107 packages in 99ms

# %%
import wandb
wandb.login()
# Out:
# True

# %%
drive.mount('/content/drive')
# !python -m thesis.src.run_pipeline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Starting model train-test pipeline for 'Overfit-Joint-MLP' (Joint Model: True)...
#
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,876
#   Class 1    | 445 / 635                  |      4,878
#   Class 2    | 172 / 245                  |      2,934
#   Class 3    | 3 / 5                      |         33
# -----------------------------------------------------------------
#  TOTAL      | 1167 / 1666                |     11,721
#   * Filtered out 590 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# [OVERFIT MODE - JOINT] Locked to chunk -> 039__039-15-007087_wid00_1 (Start: 50)               | Class: 2 | Seed: 42
#
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,876
#   Class 1    | 445 / 635                  |      4,878
#   Class 2    | 172 / 245                  |      2,934
#   Class 3    | 3 / 5                      |         33
# -----------------------------------------------------------------
#  TOTAL      | 1167 / 1666                |     11,721
#   * Filtered out 590 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# [OVERFIT MODE] Locked to chunk -> 039__039-15-007087_wid00_1 (Start: 50)               | Class: 2 | Seed: 42
#
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,876
#   Class 1    | 445 / 635                  |      4,878
#   Class 2    | 172 / 245                  |      2,934
#   Class 3    | 3 / 5                      |         33
# -----------------------------------------------------------------
#  TOTAL      | 1167 / 1666                |     11,721
#   * Filtered out 590 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# [OVERFIT MODE] Locked to chunk -> 039__039-15-007087_wid00_1 (Start: 50)               | Class: 2 | Seed: 42
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
# --- PHASE 1: TRAINING ---
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: e-j-h-leeuwenhage (e-j-h-leeuwenhage-eindhoven-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: ⢿ setting up run vaufdfej (0.0s)
# wandb: ⣻ setting up run vaufdfej (0.0s)
# wandb: ⣽ setting up run vaufdfej (0.0s)
# wandb: Tracking run with wandb version 0.29.0
# wandb: Run data is saved locally in thesis/data/processed/Overfit-Joint-MLP/wandb/run-20260828_103929-vaufdfej
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Overfit-Joint-MLP
# wandb: ⭐️ View project at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: 🚀 View run at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/vaufdfej
# /usr/local/lib/python3.13/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:881: Checkpoint directory /content/drive/My Drive/CARE-PD/thesis/data/processed/Overfit-Joint-MLP/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.13/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name      ┃ Type                  ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ backbone  │ JointBaselineBackbone │ 11.3 M │ train │     0 │
# │ 1 │ flow_head │ FlowHead              │  6.8 M │ train │     0 │
# │ 2 │ jump_head │ JumpHead              │  4.1 K │ train │     0 │
# └───┴───────────┴───────────────────────┴────────┴───────┴───────┘
# Trainable params: 18.0 M
# Non-trainable params: 0
# Total params: 18.0 M
# Total estimated model params size (MB): 72.190
# Modules in train mode: 14
# Modules in eval mode: 0
# Total FLOPs: 0
# /usr/local/lib/python3.13/dist-packages/pytorch_lightning/loops/fit_loop.py:321: The number of training batches (10) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#
# [W&B Callback] Randomly Sampling Anchor Sequences across Severity Classes...
#   -> Locked Random Anchor for Severity Class 2
# Epoch 0005/100 | Train Loss: 0.0381
#  >>> VALIDATION Epoch 0010 | MPJAE: 0.1550 rad | Label Acc: 0.9994
# Epoch 0010/100 | Train Loss: 0.0373
# Epoch 0015/100 | Train Loss: 0.0374
#  >>> VALIDATION Epoch 0020 | MPJAE: 0.1532 rad | Label Acc: 0.9996
# Epoch 0020/100 | Train Loss: 0.0374
# Epoch 0025/100 | Train Loss: 0.0349
#  >>> VALIDATION Epoch 0030 | MPJAE: 0.1479 rad | Label Acc: 0.9996
# Epoch 0030/100 | Train Loss: 0.0334
# Epoch 0035/100 | Train Loss: 0.0331
#  >>> VALIDATION Epoch 0040 | MPJAE: 0.1434 rad | Label Acc: 0.9996
# Epoch 0040/100 | Train Loss: 0.0324
# Epoch 0045/100 | Train Loss: 0.0313
#  >>> VALIDATION Epoch 0050 | MPJAE: 0.1361 rad | Label Acc: 1.0000
#
# --- [W&B Callback] Running Validation (Epoch 50) ---
#   [Time] Trajectory Generation: 1.31s
#   [Time] SMPL to H36M Batch Conversion: 77.13s
#   [Time] Metric Extraction & Plots: 136.83s
#   [Time] Anchor GIF Rendering: 16.36s
#   [Time] TOTAL Validation Routine: 231.66s
#
# Epoch 0050/100 | Train Loss: 0.0299
# Epoch 0055/100 | Train Loss: 0.0285
#  >>> VALIDATION Epoch 0060 | MPJAE: 0.1294 rad | Label Acc: 1.0000
# Epoch 0060/100 | Train Loss: 0.0278
# Epoch 0065/100 | Train Loss: 0.0264
#  >>> VALIDATION Epoch 0070 | MPJAE: 0.1219 rad | Label Acc: 0.9998
# Epoch 0070/100 | Train Loss: 0.0253
# Epoch 0075/100 | Train Loss: 0.0240
#  >>> VALIDATION Epoch 0080 | MPJAE: 0.1180 rad | Label Acc: 0.9992
# Epoch 0080/100 | Train Loss: 0.0233
# Epoch 0085/100 | Train Loss: 0.0226
#  >>> VALIDATION Epoch 0090 | MPJAE: 0.1157 rad | Label Acc: 0.9998
# Epoch 0090/100 | Train Loss: 0.0220
# Epoch 0095/100 | Train Loss: 0.0222
#  >>> VALIDATION Epoch 0100 | MPJAE: 0.1130 rad | Label Acc: 0.9996
#
# --- [W&B Callback] Running Validation (Epoch 100) ---
#   [Time] Trajectory Generation: 1.33s
#   [Time] SMPL to H36M Batch Conversion: 36.76s
#   [Time] Metric Extraction & Plots: 138.32s
#   [Time] Anchor GIF Rendering: 17.72s
#   [Time] TOTAL Validation Routine: 194.15s
#
# Epoch 0100/100 | Train Loss: 0.0211
# `Trainer.fit` stopped: `max_epochs=100` reached.
#
# --- PHASE 2: DATASET GENERATION ---
# [OVERFIT MODE] Skipping Test Generation and Evaluation.
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading console lines 64-70 (0.0s)
# wandb:
# wandb: Run history:
# wandb:                          epoch ▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇██
# wandb: eval_metrics/Overall_MPJAE_rad █▁
# wandb:               train/loss_label █▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              train/loss_motion █▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               train/loss_total █▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            trainer/global_step ▁▁▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇███
# wandb:             val/label_accuracy ▃▄▄▄██▆▁▆▄
# wandb:                  val/mpjae_rad ██▇▆▅▄▂▂▁▁
# wandb:
# wandb: Run summary:
# wandb:                          epoch 99
# wandb: eval_metrics/Overall_MPJAE_rad 0.02258
# wandb:               train/loss_label 3e-05
# wandb:              train/loss_motion 0.00701
# wandb:               train/loss_total 0.02106
# wandb:            trainer/global_step 999
# wandb:             val/label_accuracy 0.99961
# wandb:                  val/mpjae_rad 0.11296
# wandb:
# wandb: 🚀 View run Overfit-Joint-MLP at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/vaufdfej
# wandb: ⭐️ View project at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: Synced 5 W&B file(s), 2 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: thesis/data/processed/Overfit-Joint-MLP/wandb/run-20260828_103929-vaufdfej/logs
#
# Pipeline Finished Successfully!
