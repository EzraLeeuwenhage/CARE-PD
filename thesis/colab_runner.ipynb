# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
from pathlib import Path

zip_path = Path("/content/drive/MyDrive/CARE-PD/code.zip")
target_dir = Path("/content/drive/MyDrive/CARE-PD/thesis")

target_dir.mkdir(parents=True, exist_ok=True)

if not zip_path.exists():
    raise FileNotFoundError(f"Could not find '{zip_path}'.")

print(f"Unpacking '{zip_path}' into '{target_dir}'...")
shutil.unpack_archive(zip_path, extract_dir=target_dir)

print("Unpacking complete!")
# Out:
# Unpacking '/content/drive/MyDrive/CARE-PD/code.zip' into '/content/drive/MyDrive/CARE-PD/thesis'...
# Unpacking complete!

# %%
# !pip install -q uv

import os
os.chdir("/content/drive/MyDrive/CARE-PD")

# !uv pip compile pyproject.toml -o /tmp/reqs.txt
# !uv pip install --system -r /tmp/reqs.txt
# Out:
# Resolved 107 packages in 193ms
# # This file was autogenerated by uv via the following command:
# #    uv pip compile pyproject.toml -o /tmp/reqs.txt
# aiohappyeyeballs==2.7.1
#     # via aiohttp
# aiohttp==3.14.3
#     # via
#     #   fsspec
#     #   torch-geometric
# aiosignal==1.4.0
#     # via aiohttp
# alembic==1.19.1
#     # via optuna
# annotated-types==0.8.0
#     # via pydantic
# anyio==4.14.2
#     # via httpx
# attrs==26.1.0
#     # via aiohttp
# beautifulsoup4==4.15.0
#     # via
#     #   gdown
#     #   google
# certifi==2026.7.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
#     #   sentry-sdk
# charset-normalizer==3.5.1
#     # via requests
# chumpy==0.70
#     # via care-pd (pyproject.toml)
# click==8.5.0
#     # via
#     #   huggingface-hub
#     #   wandb
# colorlog==6.12.0
#     # via optuna
# contourpy==1.3.3
#     # via matplotlib
# cuda-bindings==13.3.1
#     # via torch
# cuda-pathfinder==1.8.0
#     # via cuda-bindings
# cuda-toolkit==13.0.2
#     # via torch
# cycler==0.12.1
#     # via matplotlib
# einops==0.8.1
#     # via care-pd (pyproject.toml)
# filelock==3.32.5
#     # via
#     #   gdown
#     #   huggingface-hub
#     #   torch
# fonttools==4.64.0
#     # via matplotlib
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.7.0
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   pytorch-lightning
#     #   torch
#     #   torch-geometric
# gdown==6.1.0
#     # via care-pd (pyproject.toml)
# google==3.0.0
#     # via care-pd (pyproject.toml)
# greenlet==3.1.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   sqlalchemy
# h11==0.16.0
#     # via httpcore
# hf-xet==1.6.0
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via huggingface-hub
# huggingface-hub==1.29.0
#     # via timm
# idna==3.19
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# imageio==2.31.5
#     # via care-pd (pyproject.toml)
# jinja2==3.1.6
#     # via
#     #   torch
#     #   torch-geometric
# joblib==1.4.2
#     # via
#     #   care-pd (pyproject.toml)
#     #   scikit-learn
# kiwisolver==1.5.1
#     # via matplotlib
# lightning==2.6.5
#     # via care-pd (pyproject.toml)
# lightning-utilities==0.15.3
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   torchmetrics
# mako==1.4.1
#     # via alembic
# markupsafe==3.0.3
#     # via
#     #   jinja2
#     #   mako
# matplotlib==3.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# mpmath==1.3.0
#     # via sympy
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# networkx==3.6.1
#     # via torch
# numpy==1.26.4
#     # via
#     #   care-pd (pyproject.toml)
#     #   contourpy
#     #   imageio
#     #   matplotlib
#     #   numpyencoder
#     #   optuna
#     #   pandas
#     #   scikit-learn
#     #   scipy
#     #   seaborn
#     #   smplx
#     #   torch-geometric
#     #   torchmetrics
#     #   torchvision
#     #   trimesh
# numpyencoder==0.3.0
#     # via care-pd (pyproject.toml)
# nvidia-cublas==13.1.1.3
#     # via
#     #   nvidia-cudnn-cu13
#     #   nvidia-cusolver
#     #   torch
# nvidia-cuda-cupti==13.0.85
#     # via cuda-toolkit
# nvidia-cuda-nvrtc==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cublas
# nvidia-cuda-runtime==13.0.96
#     # via cuda-toolkit
# nvidia-cudnn-cu13==9.20.0.48
#     # via torch
# nvidia-cufft==12.0.0.61
#     # via cuda-toolkit
# nvidia-cufile==1.15.1.6
#     # via cuda-toolkit
# nvidia-curand==10.4.0.35
#     # via cuda-toolkit
# nvidia-cusolver==12.0.4.66
#     # via cuda-toolkit
# nvidia-cusparse==12.6.3.3
#     # via
#     #   cuda-toolkit
#     #   nvidia-cusolver
# nvidia-cusparselt-cu13==0.8.1
#     # via torch
# nvidia-nccl-cu13==2.29.7
#     # via torch
# nvidia-nvjitlink==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cufft
#     #   nvidia-cusolver
#     #   nvidia-cusparse
# nvidia-nvshmem-cu13==3.4.5
#     # via torch
# nvidia-nvtx==13.0.85
#     # via cuda-toolkit
# opentelemetry-api==1.44.0
#     # via wandb
# optuna==4.2.1
#     # via care-pd (pyproject.toml)
# packaging==26.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   matplotlib
#     #   optuna
#     #   pytorch-lightning
#     #   torchmetrics
#     #   wandb
# pandas==2.2.3
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# pillow==12.3.0
#     # via
#     #   imageio
#     #   matplotlib
#     #   torchvision
# platformdirs==4.11.7
#     # via wandb
# propcache==0.5.2
#     # via
#     #   aiohttp
#     #   yarl
# protobuf==7.36.1
#     # via wandb
# psutil==7.2.2
#     # via torch-geometric
# pydantic==2.13.5
#     # via wandb
# pydantic-core==2.46.5
#     # via pydantic
# pyparsing==3.3.2
#     # via
#     #   matplotlib
#     #   torch-geometric
# pysocks==1.7.1
#     # via requests
# python-dateutil==2.9.0.post0
#     # via
#     #   matplotlib
#     #   pandas
# pytorch-lightning==2.6.5
#     # via lightning
# pytz==2026.3.post1
#     # via pandas
# pyyaml==6.0.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   timm
#     #   wandb
# requests==2.34.2
#     # via
#     #   gdown
#     #   torch-geometric
#     #   wandb
# safetensors==0.8.0
#     # via timm
# scikit-learn==1.6.1
#     # via care-pd (pyproject.toml)
# scipy==1.17.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   chumpy
#     #   scikit-learn
# seaborn==0.13.2
#     # via care-pd (pyproject.toml)
# sentry-sdk==2.68.1
#     # via wandb
# setuptools==75.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   torch
# six==1.17.0
#     # via
#     #   chumpy
#     #   python-dateutil
# smplx==0.1.28
#     # via care-pd (pyproject.toml)
# soupsieve==2.9.2
#     # via beautifulsoup4
# sqlalchemy==2.0.52
#     # via
#     #   alembic
#     #   optuna
# sympy==1.14.0
#     # via torch
# threadpoolctl==3.6.0
#     # via scikit-learn
# timm==1.0.15
#     # via care-pd (pyproject.toml)
# torch==2.12.1
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   smplx
#     #   timm
#     #   torch-dct
#     #   torchmetrics
#     #   torchvision
# torch-dct==0.1.6
#     # via care-pd (pyproject.toml)
# torch-geometric==2.8.0.post1
#     # via care-pd (pyproject.toml)
# torchmetrics==1.9.0
#     # via
#     #   lightning
#     #   pytorch-lightning
# torchvision==0.27.1
#     # via timm
# tqdm==4.66.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   gdown
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   torch-geometric
# trimesh==4.6.8
#     # via care-pd (pyproject.toml)
# triton==3.7.1
#     # via torch
# typing-extensions==4.16.0
#     # via
#     #   alembic
#     #   beautifulsoup4
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   opentelemetry-api
#     #   pydantic
#     #   pydantic-core
#     #   pytorch-lightning
#     #   sqlalchemy
#     #   torch
#     #   typing-inspection
#     #   wandb
# typing-inspection==0.4.4
#     # via pydantic
# tzdata==2026.3
#     # via pandas
# urllib3==2.7.0
#     # via
#     #   requests
#     #   sentry-sdk
# wandb==0.29.0
#     # via care-pd (pyproject.toml)
# xxhash==4.0.1
#     # via
#     #   torch-geometric
#     #   wandb
# yarl==1.24.5
#     # via aiohttp
# Using Python 3.13.15 environment at: /usr
# Checked 107 packages in 97ms

# %%
import wandb
wandb.login()
# Out:
# True

# %%
drive.mount('/content/drive')
# !python -m thesis.src.run_pipeline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# >>> Config Validation Passed.
#
# [ROUTER] Initializing 3D Pipeline...
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: e-j-h-leeuwenhage (e-j-h-leeuwenhage-eindhoven-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: ⢿ setting up run 2jtlmwz4 (0.0s)
# wandb: ⣻ setting up run 2jtlmwz4 (0.0s)
# wandb: ⣽ setting up run 2jtlmwz4 (0.0s)
# wandb: ⣾ setting up run 2jtlmwz4 (0.0s)
# wandb: ⣷ setting up run 2jtlmwz4 (0.5s)
# wandb: ⣯ setting up run 2jtlmwz4 (0.5s)
# wandb: Tracking run with wandb version 0.29.0
# wandb: Run data is saved locally in thesis/data/processed/Joint-MLP-Baseline-3D/wandb/run-20260902_101014-2jtlmwz4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Joint-MLP-Baseline-3D
# wandb: ⭐️ View project at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: 🚀 View run at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/2jtlmwz4
#
# Starting model train-test pipeline for 'Joint-MLP-Baseline-3D' (Joint Model: True)...
#
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,879
#   Class 1    | 445 / 635                  |      4,921
#   Class 2    | 174 / 247                  |      3,738
#   Class 3    | 24 / 33                    |        241
# -----------------------------------------------------------------
#  TOTAL      | 1190 / 1696                |     12,779
#   * Discarded 4 short sequence(s).
#
# EVAL SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 78 / 781                   |        637
#   Class 1    | 63 / 635                   |        887
#   Class 2    | 24 / 247                   |      1,036
#   Class 3    | 3 / 33                     |         25
# -----------------------------------------------------------------
#  TOTAL      | 168 / 1696                 |      2,585
#   * Discarded 4 short sequence(s).
#
# TEST SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 156 / 781                  |      1,291
#   Class 1    | 127 / 635                  |      1,409
#   Class 2    | 49 / 247                   |      1,160
#   Class 3    | 6 / 33                     |         58
# -----------------------------------------------------------------
#  TOTAL      | 338 / 1696                 |      3,918
#   * Discarded 4 short sequence(s).
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
# --- PHASE 1: TRAINING ---
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.13/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name      ┃ Type                  ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ backbone  │ JointBaselineBackbone │  6.8 M │ train │     0 │
# │ 1 │ flow_head │ FlowHead              │  3.5 M │ train │     0 │
# │ 2 │ jump_head │ JumpHead              │  4.1 K │ train │     0 │
# └───┴───────────┴───────────────────────┴────────┴───────┴───────┘
# Trainable params: 10.3 M
# Non-trainable params: 0
# Total params: 10.3 M
# Total estimated model params size (MB): 41.211
# Modules in train mode: 14
# Modules in eval mode: 0
# Total FLOPs: 0
#
# [W&B Callback] Randomly Sampling Anchor Sequences across Severity Classes...
#   -> Locked Random Anchor for Severity Class 0
#   -> Locked Random Anchor for Severity Class 1
#   -> Locked Random Anchor for Severity Class 2
#   -> Locked Random Anchor for Severity Class 3
# Epoch 0005/150 | Train Loss: 0.4873
#  >>> VALIDATION Epoch 0010 | MPJAE: 0.1667 rad | Label Acc: 0.5880
# Epoch 0010/150 | Train Loss: 0.3731
# Epoch 0015/150 | Train Loss: 0.3263
#  >>> VALIDATION Epoch 0020 | MPJAE: 0.1603 rad | Label Acc: 0.5791
# Epoch 0020/150 | Train Loss: 0.2768
# Epoch 0025/150 | Train Loss: 0.2411
#  >>> VALIDATION Epoch 0030 | MPJAE: 0.1562 rad | Label Acc: 0.5954
# Epoch 0030/150 | Train Loss: 0.2178
# Epoch 0035/150 | Train Loss: 0.1962
#  >>> VALIDATION Epoch 0040 | MPJAE: 0.1567 rad | Label Acc: 0.5988
# Epoch 0040/150 | Train Loss: 0.1791
# Epoch 0045/150 | Train Loss: 0.1677
#  >>> VALIDATION Epoch 0050 | MPJAE: 0.1555 rad | Label Acc: 0.6193
#
# --- [W&B Callback] Running Validation (Epoch 50) ---
#   [Time] Trajectory Generation: 2.53s
#   [H36MEvaluator] Processing 2585 sequences in parallel...
#   [Time] SMPL to H36M Batch Conversion: 9.61s
#   [SMPLEvaluator] Processing 2585 sequences in parallel...
#   [H36MEvaluator] Processing 2585 sequences in parallel...
# Saved dataset summary plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03e_sparc_all_24_joints.png
#   [Time] Metric Extraction & Plots: 34.44s
#   [Time] Anchor GIF Rendering: 62.65s
#   [Time] TOTAL Validation Routine: 112.62s
#
# Epoch 0050/150 | Train Loss: 0.1553
# Epoch 0055/150 | Train Loss: 0.1385
#  >>> VALIDATION Epoch 0060 | MPJAE: 0.1577 rad | Label Acc: 0.6437
# Epoch 0060/150 | Train Loss: 0.1341
# Saved dataset summary plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03e_sparc_all_24_joints.png
#   [Time] Metric Extraction & Plots: 39.14s
#   [Time] Anchor GIF Rendering: 61.82s
#   [Time] TOTAL Validation Routine: 108.06s
#
# Epoch 0100/150 | Train Loss: 0.1008
# Epoch 0105/150 | Train Loss: 0.0982
#  >>> VALIDATION Epoch 0110 | MPJAE: 0.1613 rad | Label Acc: 0.6580
# Epoch 0110/150 | Train Loss: 0.0952
# Epoch 0115/150 | Train Loss: 0.0893
#  >>> VALIDATION Epoch 0120 | MPJAE: 0.1647 rad | Label Acc: 0.6433
# Epoch 0120/150 | Train Loss: 0.1148
# Epoch 0125/150 | Train Loss: 0.0969
#  >>> VALIDATION Epoch 0130 | MPJAE: 0.1629 rad | Label Acc: 0.6429
# Epoch 0130/150 | Train Loss: 0.0745
# Epoch 0135/150 | Train Loss: 0.0842
#  >>> VALIDATION Epoch 0140 | MPJAE: 0.1633 rad | Label Acc: 0.6116
# Epoch 0140/150 | Train Loss: 0.0926
# Epoch 0145/150 | Train Loss: 0.0941
#  >>> VALIDATION Epoch 0150 | MPJAE: 0.1601 rad | Label Acc: 0.6236
#
# --- [W&B Callback] Running Validation (Epoch 150) ---
#   [Time] Trajectory Generation: 2.72s
#   [Time] SMPL to H36M Batch Conversion: 2.21s
#   [SMPLEvaluator] Processing 2585 sequences in parallel...
# /usr/local/lib/python3.13/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
#   [H36MEvaluator] Processing 2585 sequences in parallel...
# Saved dataset summary plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations/03e_sparc_all_24_joints.png
#   [Time] Metric Extraction & Plots: 39.14s
#   [Time] Anchor GIF Rendering: 62.29s
#   [Time] TOTAL Validation Routine: 108.64s
#
# Epoch 0150/150 | Train Loss: 0.0769
# `Trainer.fit` stopped: `max_epochs=150` reached.
#
# --- PHASE 2: DATASET GENERATION ---
# Loading best checkpoint from: /content/drive/My Drive/CARE-PD/thesis/data/processed/Joint-MLP-Baseline-3D/checkpoints/best-epoch=49-val/mpjae_rad=0.1555.ckpt
#
# --- PHASE 2.5: CONDITIONAL ADHERENCE (LABEL ACCURACY) ---
# Final Test Label Accuracy: 0.5781 (2265/3918 matches)
#
# --- PHASE 3: FORMAT CONVERSION ---
# Formatting and caching raw 3D sequences...
# Formatting Ground Truth to SMPL...
# Saved generated SMPL data to: thesis/data/processed/Joint-MLP-Baseline-3D/SMPL/ground_truth.pkl
# Converting Ground Truth SMPL -> H36M (This takes a moment)...
# Input Data: thesis/data/processed/Joint-MLP-Baseline-3D/SMPL/ground_truth.pkl
# Output Dir: thesis/data/processed/Joint-MLP-Baseline-3D/h36m
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Converting ground_truth to 3D World Coords:   0% 0/1 [00:00<?, ?it/s]
# Processing GT:   0% 0/3918 [00:00<?, ?it/s]
# Processing GT:   1% 25/3918 [00:00<00:15, 247.64it/s]
# Processing GT:   1% 51/3918 [00:00<00:15, 249.40it/s]
# Processing GT:   2% 76/3918 [00:00<00:15, 249.45it/s]
# Processing GT:   3% 101/3918 [00:00<00:15, 249.50it/s]
# Processing GT:   3% 127/3918 [00:00<00:15, 249.97it/s]
# Processing GT:   4% 152/3918 [00:00<00:15, 249.70it/s]
# Processing GT:   5% 178/3918 [00:00<00:14, 250.21it/s]
# Processing GT:   5% 204/3918 [00:00<00:14, 250.64it/s]
# Processing GT:   6% 230/3918 [00:00<00:14, 250.90it/s]
# Processing GT:   7% 256/3918 [00:01<00:14, 250.79it/s]
# Processing GT:   7% 282/3918 [00:01<00:14, 250.37it/s]
# Processing GT:   8% 308/3918 [00:01<00:14, 248.74it/s]
# Processing GT:   9% 334/3918 [00:01<00:14, 249.25it/s]
# Processing GT:   9% 359/3918 [00:01<00:14, 248.66it/s]
# Processing GT:  10% 384/3918 [00:01<00:14, 247.75it/s]
# Processing GT:  10% 409/3918 [00:01<00:14, 248.20it/s]
# Processing GT:  11% 435/3918 [00:01<00:13, 249.01it/s]
# Processing GT:  12% 461/3918 [00:01<00:13, 249.69it/s]
# Processing GT:  12% 486/3918 [00:01<00:13, 249.66it/s]
# Processing GT:  13% 512/3918 [00:02<00:13, 249.92it/s]
# Processing GT:  14% 537/3918 [00:02<00:13, 249.68it/s]
# Processing GT: 100% 3918/3918 [00:15<00:00, 248.28it/s]
# Converting ground_truth to 3D World Coords: 100% 1/1 [00:15<00:00, 15.78s/it]
# Formatting Generated data to SMPL...
# Saved generated SMPL data to: thesis/data/processed/Joint-MLP-Baseline-3D/SMPL/generated.pkl
# Converting Generated SMPL -> H36M...
# Input Data: thesis/data/processed/Joint-MLP-Baseline-3D/SMPL/generated.pkl
# Output Dir: thesis/data/processed/Joint-MLP-Baseline-3D/h36m
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Converting generated to 3D World Coords:   0% 0/1 [00:00<?, ?it/s]
# Processing GEN:   0% 0/3918 [00:00<?, ?it/s]
# Processing GEN:   1% 26/3918 [00:00<00:15, 251.17it/s]
# Processing GEN:   1% 52/3918 [00:00<00:15, 252.41it/s]
# Processing GEN:   2% 78/3918 [00:00<00:15, 252.32it/s]
# Processing GEN:   3% 104/3918 [00:00<00:15, 251.98it/s]
# Processing GEN:   3% 130/3918 [00:00<00:15, 251.51it/s]
# Processing GEN:   4% 156/3918 [00:00<00:14, 251.42it/s]
# Processing GEN:   5% 182/3918 [00:00<00:14, 251.70it/s]
# Processing GEN:   5% 208/3918 [00:00<00:14, 251.75it/s]
# Processing GEN:   6% 234/3918 [00:00<00:14, 251.72it/s]
# Processing GEN:   7% 260/3918 [00:01<00:14, 251.72it/s]
# Processing GEN:   7% 286/3918 [00:01<00:14, 251.91it/s]
# Processing GEN:   8% 312/3918 [00:01<00:14, 251.73it/s]
# Processing GEN:   9% 338/3918 [00:01<00:14, 251.79it/s]
# Processing GEN:   9% 364/3918 [00:01<00:14, 251.81it/s]
# Processing GEN:  10% 390/3918 [00:01<00:14, 251.66it/s]
# Processing GEN:  11% 416/3918 [00:01<00:13, 251.72it/s]
# Processing GEN:  11% 442/3918 [00:01<00:13, 251.59it/s]
# Processing GEN:  12% 468/3918 [00:01<00:13, 251.57it/s]
# Processing GEN:  13% 494/3918 [00:01<00:13, 251.69it/s]
# Processing GEN:  13% 520/3918 [00:02<00:13, 251.50it/s]
# Processing GEN:  14% 546/3918 [00:02<00:13, 251.53it/s]
# Processing GEN:  15% 572/3918 [00:02<00:13, 251.32it/s]
# Processing GEN:  15% 598/3918 [00:02<00:13, 251.42it/s]
# Processing GEN:  16% 624/3918 [00:02<00:13, 249.14it/s]
# Processing GEN:  17% 650/3918 [00:02<00:13, 249.68it/s]
# Processing GEN:  17% 676/3918 [00:02<00:12, 250.14it/s]
# Processing GEN:  18% 702/3918 [00:02<00:12, 250.50it/s]
# Processing GEN:  19% 728/3918 [00:02<00:12, 250.79it/s]
# Processing GEN:  19% 754/3918 [00:03<00:12, 250.66it/s]
# Processing GEN:  20% 780/3918 [00:03<00:12, 250.95it/s]
# Processing GEN:  21% 806/3918 [00:03<00:12, 250.92it/s]
# Processing GEN:  21% 832/3918 [00:03<00:12, 251.20it/s]
# Processing GEN:  22% 858/3918 [00:03<00:12, 250.87it/s]
# Processing GEN:  23% 884/3918 [00:03<00:12, 250.88it/s]
# Processing GEN:  79% 3089/3918 [00:12<00:03, 251.58it/s]
# Processing GEN:  80% 3115/3918 [00:12<00:03, 251.76it/s]
# Processing GEN:  80% 3141/3918 [00:12<00:03, 251.83it/s]
# Processing GEN:  81% 3167/3918 [00:12<00:02, 252.08it/s]
# Processing GEN:  81% 3193/3918 [00:12<00:02, 252.35it/s]
# Processing GEN:  82% 3219/3918 [00:12<00:02, 252.24it/s]
# Processing GEN:  83% 3245/3918 [00:13<00:02, 252.02it/s]
# Processing GEN:  83% 3271/3918 [00:13<00:02, 251.63it/s]
# Processing GEN:  84% 3297/3918 [00:13<00:02, 251.45it/s]
# Processing GEN:  85% 3323/3918 [00:13<00:02, 251.26it/s]
# Processing GEN:  85% 3349/3918 [00:13<00:02, 251.20it/s]
# Processing GEN:  86% 3375/3918 [00:13<00:02, 251.29it/s]
# Processing GEN:  87% 3401/3918 [00:13<00:02, 251.43it/s]
# Processing GEN:  87% 3427/3918 [00:13<00:01, 248.18it/s]
# Processing GEN:  88% 3452/3918 [00:13<00:01, 248.43it/s]
# Processing GEN:  89% 3477/3918 [00:13<00:01, 245.02it/s]
# Processing GEN:  89% 3503/3918 [00:14<00:01, 246.75it/s]
# Processing GEN:  90% 3529/3918 [00:14<00:01, 248.41it/s]
# Processing GEN:  91% 3555/3918 [00:14<00:01, 249.49it/s]
# Processing GEN:  91% 3581/3918 [00:14<00:01, 250.46it/s]
# Processing GEN:  92% 3607/3918 [00:14<00:01, 251.03it/s]
# Processing GEN:  93% 3633/3918 [00:14<00:01, 251.25it/s]
# Processing GEN:  93% 3659/3918 [00:14<00:01, 251.45it/s]
# Processing GEN:  94% 3685/3918 [00:14<00:00, 251.50it/s]
# Processing GEN:  95% 3711/3918 [00:14<00:00, 249.95it/s]
# Processing GEN:  95% 3737/3918 [00:14<00:00, 250.44it/s]
# Processing GEN:  96% 3763/3918 [00:15<00:00, 250.36it/s]
# Processing GEN:  97% 3789/3918 [00:15<00:00, 249.92it/s]
# Processing GEN:  97% 3815/3918 [00:15<00:00, 250.26it/s]
# Processing GEN:  98% 3841/3918 [00:15<00:00, 250.62it/s]
# Processing GEN:  99% 3867/3918 [00:15<00:00, 251.08it/s]
# Processing GEN: 100% 3918/3918 [00:15<00:00, 249.54it/s]
# Converting generated to 3D World Coords: 100% 1/1 [00:15<00:00, 15.70s/it]
#
# --- PHASE 4: EVALUATION ---
#
# Processing dataset: thesis/data/processed/Joint-MLP-Baseline-3D/h36m/ground_truth_3d_world.npz
#   [H36MEvaluator] Processing 3918 sequences in parallel...
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/Joint-MLP-Baseline-3D/evaluation/gt_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/Joint-MLP-Baseline-3D/h36m/gt_heel_strikes.json
#
# Processing dataset: thesis/data/processed/Joint-MLP-Baseline-3D/h36m/generated_3d_world.npz
#   [H36MEvaluator] Processing 3918 sequences in parallel...
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/Joint-MLP-Baseline-3D/evaluation/gen_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/Joint-MLP-Baseline-3D/h36m/gen_heel_strikes.json
#   [SMPLEvaluator] Processing 3918 sequences in parallel...
#
# Generating and saving Final Test Set visualizations...
# Saved dataset summary plot to: thesis/visualizations/Joint-MLP-Baseline-3D/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/visualizations/Joint-MLP-Baseline-3D/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/visualizations/Joint-MLP-Baseline-3D/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/visualizations/Joint-MLP-Baseline-3D/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/visualizations/Joint-MLP-Baseline-3D/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/visualizations/Joint-MLP-Baseline-3D/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/visualizations/Joint-MLP-Baseline-3D/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/visualizations/Joint-MLP-Baseline-3D/03e_sparc_all_24_joints.png
# Final Test visual artifacts saved permanently to: thesis/visualizations/Joint-MLP-Baseline-3D
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb:
# wandb: Run history:
# wandb:                                        epoch ▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇███
# wandb:             eval_metrics/Mean_Hellinger_H36M ▁█▆
# wandb:             eval_metrics/Mean_Hellinger_SMPL ▁▆█
# wandb:                    eval_metrics/Mean_KS_H36M ▁██
# wandb:                    eval_metrics/Mean_KS_SMPL ▁▆█
# wandb:               eval_metrics/Overall_MPJAE_rad ▁█▆
# wandb:          physical_realism/floating_error_abs ▁▂█
# wandb: physical_realism/foot_displacement_error_abs ▁▄█
# wandb:                             train/loss_label █▇▆▆▅▄▄▄▃▃▃▃▂▂▃▂▂▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                            train/loss_motion █▄▃▃▂▂▂▂▂▂▁▂▁▂▁▁▁▁▁▂▁▁▁▂▂▁▁▂▂▁▁▂▁▁▂▂▂▂▁▂
# wandb:                                           +4 ...
# wandb:
# wandb: Run summary:
# wandb:                                        epoch 149
# wandb:             eval_metrics/Mean_Hellinger_H36M 0.48153
# wandb:             eval_metrics/Mean_Hellinger_SMPL 0.342
# wandb:                    eval_metrics/Mean_KS_H36M 0.45756
# wandb:                    eval_metrics/Mean_KS_SMPL 0.35026
# wandb:               eval_metrics/Overall_MPJAE_rad 0.03571
# wandb:          physical_realism/floating_error_abs 0.06152
# wandb: physical_realism/foot_displacement_error_abs 0.11254
# wandb:                             train/loss_label 0.03864
# wandb:                            train/loss_motion 0.03826
# wandb:                                           +4 ...
# wandb:
# wandb: 🚀 View run Joint-MLP-Baseline-3D at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/2jtlmwz4
# wandb: ⭐️ View project at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: Synced 5 W&B file(s), 66 media file(s), 24 artifact file(s) and 0 other file(s)
# wandb: Find logs at: thesis/data/processed/Joint-MLP-Baseline-3D/wandb/run-20260902_101014-2jtlmwz4/logs
#
# Pipeline Finished Successfully!
