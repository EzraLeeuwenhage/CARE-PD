# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
from pathlib import Path

zip_path = Path("/content/drive/MyDrive/CARE-PD/code.zip")
target_dir = Path("/content/drive/MyDrive/CARE-PD/thesis")

target_dir.mkdir(parents=True, exist_ok=True)

if not zip_path.exists():
    raise FileNotFoundError(f"Could not find '{zip_path}'.")

print(f"Unpacking '{zip_path}' into '{target_dir}'...")
shutil.unpack_archive(zip_path, extract_dir=target_dir)

print("Unpacking complete!")
# Out:
# Unpacking '/content/drive/MyDrive/CARE-PD/code.zip' into '/content/drive/MyDrive/CARE-PD/thesis'...
# Unpacking complete!

# %%
# !pip install -q uv

import os
os.chdir("/content/drive/MyDrive/CARE-PD")

# !uv pip compile pyproject.toml -o /tmp/reqs.txt
# !uv pip install --system -r /tmp/reqs.txt
# Out:
# Resolved 106 packages in 22ms
# # This file was autogenerated by uv via the following command:
# #    uv pip compile pyproject.toml -o /tmp/reqs.txt
# aiohappyeyeballs==2.7.1
#     # via aiohttp
# aiohttp==3.14.3
#     # via
#     #   fsspec
#     #   torch-geometric
# aiosignal==1.4.0
#     # via aiohttp
# alembic==1.19.1
#     # via optuna
# annotated-types==0.8.0
#     # via pydantic
# anyio==4.14.2
#     # via httpx
# attrs==26.1.0
#     # via aiohttp
# beautifulsoup4==4.15.0
#     # via
#     #   gdown
#     #   google
# certifi==2026.7.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
#     #   sentry-sdk
# charset-normalizer==3.4.9
#     # via requests
# chumpy==0.70
#     # via care-pd (pyproject.toml)
# click==8.4.2
#     # via
#     #   huggingface-hub
#     #   wandb
# colorlog==6.12.0
#     # via optuna
# contourpy==1.3.3
#     # via matplotlib
# cuda-bindings==13.3.1
#     # via torch
# cuda-pathfinder==1.6.0
#     # via cuda-bindings
# cuda-toolkit==13.0.2
#     # via torch
# cycler==0.12.1
#     # via matplotlib
# einops==0.8.1
#     # via care-pd (pyproject.toml)
# filelock==3.32.2
#     # via
#     #   gdown
#     #   huggingface-hub
#     #   torch
# fonttools==4.63.0
#     # via matplotlib
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.7.0
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   pytorch-lightning
#     #   torch
#     #   torch-geometric
# gdown==6.1.0
#     # via care-pd (pyproject.toml)
# google==3.0.0
#     # via care-pd (pyproject.toml)
# greenlet==3.1.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   sqlalchemy
# h11==0.16.0
#     # via httpcore
# hf-xet==1.6.0
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via huggingface-hub
# huggingface-hub==1.27.0
#     # via timm
# idna==3.18
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# imageio==2.31.5
#     # via care-pd (pyproject.toml)
# jinja2==3.1.6
#     # via
#     #   torch
#     #   torch-geometric
# joblib==1.4.2
#     # via
#     #   care-pd (pyproject.toml)
#     #   scikit-learn
# kiwisolver==1.5.0
#     # via matplotlib
# lightning==2.6.5
#     # via care-pd (pyproject.toml)
# lightning-utilities==0.15.3
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   torchmetrics
# mako==1.4.1
#     # via alembic
# markupsafe==3.0.3
#     # via
#     #   jinja2
#     #   mako
# matplotlib==3.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# mpmath==1.3.0
#     # via sympy
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# networkx==3.6.1
#     # via torch
# numpy==1.26.4
#     # via
#     #   care-pd (pyproject.toml)
#     #   contourpy
#     #   imageio
#     #   matplotlib
#     #   numpyencoder
#     #   optuna
#     #   pandas
#     #   scikit-learn
#     #   scipy
#     #   seaborn
#     #   smplx
#     #   torch-geometric
#     #   torchmetrics
#     #   torchvision
#     #   trimesh
# numpyencoder==0.3.0
#     # via care-pd (pyproject.toml)
# nvidia-cublas==13.1.1.3
#     # via
#     #   nvidia-cudnn-cu13
#     #   nvidia-cusolver
#     #   torch
# nvidia-cuda-cupti==13.0.85
#     # via cuda-toolkit
# nvidia-cuda-nvrtc==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cublas
# nvidia-cuda-runtime==13.0.96
#     # via cuda-toolkit
# nvidia-cudnn-cu13==9.20.0.48
#     # via torch
# nvidia-cufft==12.0.0.61
#     # via cuda-toolkit
# nvidia-cufile==1.15.1.6
#     # via cuda-toolkit
# nvidia-curand==10.4.0.35
#     # via cuda-toolkit
# nvidia-cusolver==12.0.4.66
#     # via cuda-toolkit
# nvidia-cusparse==12.6.3.3
#     # via
#     #   cuda-toolkit
#     #   nvidia-cusolver
# nvidia-cusparselt-cu13==0.8.1
#     # via torch
# nvidia-nccl-cu13==2.29.7
#     # via torch
# nvidia-nvjitlink==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cufft
#     #   nvidia-cusolver
#     #   nvidia-cusparse
# nvidia-nvshmem-cu13==3.4.5
#     # via torch
# nvidia-nvtx==13.0.85
#     # via cuda-toolkit
# optuna==4.2.1
#     # via care-pd (pyproject.toml)
# packaging==26.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   matplotlib
#     #   optuna
#     #   pytorch-lightning
#     #   torchmetrics
#     #   wandb
# pandas==2.2.3
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# pillow==12.3.0
#     # via
#     #   imageio
#     #   matplotlib
#     #   torchvision
# platformdirs==4.11.2
#     # via wandb
# propcache==0.5.2
#     # via
#     #   aiohttp
#     #   yarl
# protobuf==7.35.1
#     # via wandb
# psutil==7.2.2
#     # via torch-geometric
# pydantic==2.13.4
#     # via wandb
# pydantic-core==2.46.4
#     # via pydantic
# pyparsing==3.3.2
#     # via
#     #   matplotlib
#     #   torch-geometric
# pysocks==1.7.1
#     # via requests
# python-dateutil==2.9.0.post0
#     # via
#     #   matplotlib
#     #   pandas
# pytorch-lightning==2.6.5
#     # via lightning
# pytz==2026.3.post1
#     # via pandas
# pyyaml==6.0.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   timm
#     #   wandb
# requests==2.34.2
#     # via
#     #   gdown
#     #   torch-geometric
#     #   wandb
# safetensors==0.8.0
#     # via timm
# scikit-learn==1.6.1
#     # via care-pd (pyproject.toml)
# scipy==1.17.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   chumpy
#     #   scikit-learn
# seaborn==0.13.2
#     # via care-pd (pyproject.toml)
# sentry-sdk==2.67.1
#     # via wandb
# setuptools==75.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   torch
# six==1.17.0
#     # via
#     #   chumpy
#     #   python-dateutil
# smplx==0.1.28
#     # via care-pd (pyproject.toml)
# soupsieve==2.9.2
#     # via beautifulsoup4
# sqlalchemy==2.0.51
#     # via
#     #   alembic
#     #   optuna
# sympy==1.14.0
#     # via torch
# threadpoolctl==3.6.0
#     # via scikit-learn
# timm==1.0.15
#     # via care-pd (pyproject.toml)
# torch==2.12.1
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   smplx
#     #   timm
#     #   torch-dct
#     #   torchmetrics
#     #   torchvision
# torch-dct==0.1.6
#     # via care-pd (pyproject.toml)
# torch-geometric==2.8.0.post1
#     # via care-pd (pyproject.toml)
# torchmetrics==1.9.0
#     # via
#     #   lightning
#     #   pytorch-lightning
# torchvision==0.27.1
#     # via timm
# tqdm==4.66.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   gdown
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   torch-geometric
# trimesh==4.6.8
#     # via care-pd (pyproject.toml)
# triton==3.7.1
#     # via torch
# typing-extensions==4.16.0
#     # via
#     #   aiohttp
#     #   aiosignal
#     #   alembic
#     #   anyio
#     #   beautifulsoup4
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   pydantic
#     #   pydantic-core
#     #   pytorch-lightning
#     #   sqlalchemy
#     #   torch
#     #   typing-inspection
#     #   wandb
# typing-inspection==0.4.3
#     # via pydantic
# tzdata==2026.3
#     # via pandas
# urllib3==2.7.0
#     # via
#     #   requests
#     #   sentry-sdk
# wandb==0.28.1
#     # via care-pd (pyproject.toml)
# xxhash==3.8.1
#     # via torch-geometric
# yarl==1.24.5
#     # via aiohttp
# Using Python 3.12.13 environment at: /usr
# Checked 106 packages in 99ms

# %%
import wandb
wandb.login()
# Out:
# True

# %%
drive.mount('/content/drive')
# !python -m thesis.src.run_pipeline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Starting model train-test pipeline for 'JointModel-MLP-Baseline' (Joint Model: True)...
#
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,876
#   Class 1    | 445 / 635                  |      4,878
#   Class 2    | 172 / 245                  |      2,934
#   Class 3    | 3 / 5                      |         33
# -----------------------------------------------------------------
#  TOTAL      | 1167 / 1666                |     11,721
#   * Filtered out 590 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# EVAL SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 78 / 781                   |        630
#   Class 1    | 63 / 635                   |        876
#   Class 2    | 24 / 245                   |        463
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 166 / 1666                 |      1,979
#   * Filtered out 591 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# TEST SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 156 / 781                  |      1,289
#   Class 1    | 127 / 635                  |      1,401
#   Class 2    | 49 / 245                   |      1,107
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 333 / 1666                 |      3,807
#   * Filtered out 63 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
# --- PHASE 1: TRAINING ---
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: e-j-h-leeuwenhage (e-j-h-leeuwenhage-eindhoven-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run y34i6gc9 (0.3s)
# wandb: ⣯ setting up run y34i6gc9 (0.3s)
# wandb: ⣟ setting up run y34i6gc9 (0.3s)
# wandb: ⡿ setting up run y34i6gc9 (0.3s)
# wandb: ⢿ setting up run y34i6gc9 (0.3s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in thesis/data/processed/JointModel-MLP-Baseline/wandb/run-20260811_112857-y34i6gc9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run JointModel-MLP-Baseline
# wandb: ⭐️ View project at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: 🚀 View run at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/y34i6gc9
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name      ┃ Type                  ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ backbone  │ JointBaselineBackbone │ 11.3 M │ train │     0 │
# │ 1 │ flow_head │ FlowHead              │  6.8 M │ train │     0 │
# │ 2 │ jump_head │ JumpHead              │  4.1 K │ train │     0 │
# └───┴───────────┴───────────────────────┴────────┴───────┴───────┘
# Trainable params: 18.0 M
# Non-trainable params: 0
# Total params: 18.0 M
# Total estimated model params size (MB): 72.190
# Modules in train mode: 14
# Modules in eval mode: 0
# Total FLOPs: 0
# Epoch 0005/150 | Train Loss: 0.6618
#  >>> VALIDATION Epoch 0010 | MPJAE: 0.1724 rad | Label Acc: 0.6301
# Epoch 0010/150 | Train Loss: 0.5703
# Epoch 0015/150 | Train Loss: 0.5067
#  >>> VALIDATION Epoch 0020 | MPJAE: 0.1764 rad | Label Acc: 0.4952
# Epoch 0020/150 | Train Loss: 0.4633
# Epoch 0025/150 | Train Loss: 0.4215
#  >>> VALIDATION Epoch 0030 | MPJAE: 0.1738 rad | Label Acc: 0.5488
# Epoch 0030/150 | Train Loss: 0.3923
# Epoch 0035/150 | Train Loss: 0.3649
#  >>> VALIDATION Epoch 0040 | MPJAE: 0.1786 rad | Label Acc: 0.5594
# Epoch 0040/150 | Train Loss: 0.3417
# Epoch 0045/150 | Train Loss: 0.3190
#  >>> VALIDATION Epoch 0050 | MPJAE: 0.1826 rad | Label Acc: 0.5371
# Epoch 0050/150 | Train Loss: 0.2977
# Epoch 0055/150 | Train Loss: 0.2810
#  >>> VALIDATION Epoch 0060 | MPJAE: 0.1873 rad | Label Acc: 0.5104
# Epoch 0060/150 | Train Loss: 0.2615
# Epoch 0065/150 | Train Loss: 0.2493
#  >>> VALIDATION Epoch 0070 | MPJAE: 0.1876 rad | Label Acc: 0.5083
# Epoch 0070/150 | Train Loss: 0.2489
# Epoch 0075/150 | Train Loss: 0.2328
#  >>> VALIDATION Epoch 0080 | MPJAE: 0.1887 rad | Label Acc: 0.5205
# Epoch 0080/150 | Train Loss: 0.2145
# Epoch 0085/150 | Train Loss: 0.2095
#  >>> VALIDATION Epoch 0090 | MPJAE: 0.1898 rad | Label Acc: 0.5629
# Epoch 0090/150 | Train Loss: 0.1981
# Epoch 0095/150 | Train Loss: 0.1881
#  >>> VALIDATION Epoch 0100 | MPJAE: 0.1871 rad | Label Acc: 0.5760
# Epoch 0100/150 | Train Loss: 0.1691
# Epoch 0105/150 | Train Loss: 0.1881
#  >>> VALIDATION Epoch 0110 | MPJAE: 0.1895 rad | Label Acc: 0.4967
# Epoch 0110/150 | Train Loss: 0.1762
# Epoch 0115/150 | Train Loss: 0.1784
#  >>> VALIDATION Epoch 0120 | MPJAE: 0.1961 rad | Label Acc: 0.5099
# Epoch 0120/150 | Train Loss: 0.1462
# Epoch 0125/150 | Train Loss: 0.1587
#  >>> VALIDATION Epoch 0130 | MPJAE: 0.1946 rad | Label Acc: 0.5710
# Epoch 0130/150 | Train Loss: 0.1430
# Epoch 0135/150 | Train Loss: 0.1645
#  >>> VALIDATION Epoch 0140 | MPJAE: 0.1989 rad | Label Acc: 0.5841
# Epoch 0140/150 | Train Loss: 0.1503
# Epoch 0145/150 | Train Loss: 0.1406
#  >>> VALIDATION Epoch 0150 | MPJAE: 0.1993 rad | Label Acc: 0.5563
# Epoch 0150/150 | Train Loss: 0.1391
# `Trainer.fit` stopped: `max_epochs=150` reached.
#
# --- PHASE 2: DATASET GENERATION ---
# Loading best checkpoint from: /content/drive/My Drive/CARE-PD/thesis/data/processed/JointModel-MLP-Baseline/checkpoints/best-epoch=09-val/mpjae_rad=0.1724.ckpt
#
# --- PHASE 2.5: CONDITIONAL ADHERENCE (LABEL ACCURACY) ---
# Final Test Label Accuracy: 0.6302 (2399/3807 matches)
#
# --- PHASE 3: FORMAT CONVERSION ---
# Formatting and caching raw 6D sequences...
# Formatting Ground Truth to SMPL...
# Saved generated SMPL data to: thesis/data/processed/JointModel-MLP-Baseline/SMPL/ground_truth.pkl
# Converting Ground Truth SMPL -> H36M (This takes a moment)...
# Input Data: thesis/data/processed/JointModel-MLP-Baseline/SMPL/ground_truth.pkl
# Output Dir: thesis/data/processed/JointModel-MLP-Baseline/h36m
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Converting ground_truth to 3D World Coords:   0% 0/1 [00:00<?, ?it/s]
# Processing GT:   0% 0/3807 [00:00<?, ?it/s]
# Processing GT:   0% 17/3807 [00:00<00:22, 169.40it/s]
# Processing GT:   1% 43/3807 [00:00<00:17, 220.04it/s]
# Processing GT:   2% 69/3807 [00:00<00:15, 235.77it/s]
# Processing GT:   2% 95/3807 [00:00<00:15, 243.24it/s]
# Processing GT:   3% 121/3807 [00:00<00:14, 247.62it/s]
# Processing GT:   4% 147/3807 [00:00<00:14, 250.31it/s]
# Processing GT:   5% 173/3807 [00:00<00:14, 251.97it/s]
# Processing GT:   5% 199/3807 [00:00<00:14, 253.22it/s]
# Processing GT:   6% 225/3807 [00:00<00:14, 253.86it/s]
# Processing GT:   7% 251/3807 [00:01<00:13, 254.51it/s]
# Processing GT:   7% 277/3807 [00:01<00:13, 255.15it/s]
# Processing GT:   8% 303/3807 [00:01<00:13, 255.26it/s]
# Processing GT:   9% 329/3807 [00:01<00:13, 255.27it/s]
# Processing GT:   9% 355/3807 [00:01<00:13, 255.45it/s]
# Converting ground_truth to 3D World Coords: 100% 1/1 [00:15<00:00, 15.08s/it]
# Formatting Generated data to SMPL...
# Saved generated SMPL data to: thesis/data/processed/JointModel-MLP-Baseline/SMPL/generated.pkl
# Converting Generated SMPL -> H36M...
# Input Data: thesis/data/processed/JointModel-MLP-Baseline/SMPL/generated.pkl
# Output Dir: thesis/data/processed/JointModel-MLP-Baseline/h36m
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Converting generated to 3D World Coords:   0% 0/1 [00:00<?, ?it/s]
# Processing GEN:   0% 0/3807 [00:00<?, ?it/s]
# Processing GEN:   1% 26/3807 [00:00<00:14, 252.15it/s]
# Processing GEN:   1% 52/3807 [00:00<00:14, 253.82it/s]
# Processing GEN:   2% 78/3807 [00:00<00:14, 253.87it/s]
# Processing GEN:   3% 104/3807 [00:00<00:14, 254.97it/s]
# Processing GEN:   3% 130/3807 [00:00<00:14, 254.61it/s]
# Processing GEN:   4% 156/3807 [00:00<00:14, 253.84it/s]
# Processing GEN:   5% 182/3807 [00:00<00:14, 254.42it/s]
# Processing GEN:   5% 208/3807 [00:00<00:14, 254.28it/s]
# Processing GEN:   6% 234/3807 [00:00<00:14, 252.29it/s]
# Processing GEN:   7% 260/3807 [00:01<00:14, 250.32it/s]
# Processing GEN:   8% 286/3807 [00:01<00:14, 249.27it/s]
# Processing GEN:   8% 311/3807 [00:01<00:14, 248.81it/s]
# Processing GEN:   9% 336/3807 [00:01<00:13, 248.55it/s]
# Processing GEN:   9% 361/3807 [00:01<00:13, 248.10it/s]
# Processing GEN:  10% 386/3807 [00:01<00:13, 247.92it/s]
# Processing GEN:  11% 411/3807 [00:01<00:13, 247.24it/s]
# Processing GEN:  11% 436/3807 [00:01<00:13, 247.09it/s]
# Processing GEN:  12% 461/3807 [00:01<00:13, 247.41it/s]
# Processing GEN:  13% 486/3807 [00:01<00:13, 247.34it/s]
# Processing GEN:  13% 511/3807 [00:02<00:13, 247.45it/s]
# Processing GEN:  14% 536/3807 [00:02<00:13, 247.48it/s]
# Processing GEN:  15% 562/3807 [00:02<00:13, 248.55it/s]
# Processing GEN:  15% 588/3807 [00:02<00:12, 249.27it/s]
# Processing GEN:  16% 613/3807 [00:02<00:12, 249.44it/s]
# Processing GEN:  17% 638/3807 [00:02<00:12, 249.38it/s]
# Processing GEN:  17% 663/3807 [00:02<00:12, 247.32it/s]
# Processing GEN:  18% 688/3807 [00:02<00:12, 247.12it/s]
# Processing GEN:  19% 713/3807 [00:02<00:12, 247.51it/s]
# Processing GEN:  19% 738/3807 [00:02<00:12, 247.61it/s]
# Processing GEN:  20% 763/3807 [00:03<00:12, 248.18it/s]
# Processing GEN:  21% 788/3807 [00:03<00:12, 248.67it/s]
# Processing GEN:  21% 814/3807 [00:03<00:12, 249.22it/s]
# Processing GEN:  22% 840/3807 [00:03<00:11, 249.79it/s]
# Processing GEN:  23% 866/3807 [00:03<00:11, 250.01it/s]
# Processing GEN:  23% 892/3807 [00:03<00:11, 250.97it/s]
# Processing GEN:  82% 3111/3807 [00:12<00:02, 247.34it/s]
# Processing GEN:  82% 3136/3807 [00:12<00:02, 247.29it/s]
# Processing GEN:  83% 3161/3807 [00:12<00:02, 247.15it/s]
# Processing GEN:  84% 3186/3807 [00:12<00:02, 247.39it/s]
# Processing GEN:  84% 3211/3807 [00:12<00:02, 246.74it/s]
# Processing GEN:  85% 3236/3807 [00:12<00:02, 247.16it/s]
# Processing GEN:  86% 3261/3807 [00:13<00:02, 247.18it/s]
# Processing GEN:  86% 3286/3807 [00:13<00:02, 246.74it/s]
# Processing GEN:  87% 3311/3807 [00:13<00:02, 246.76it/s]
# Processing GEN:  88% 3336/3807 [00:13<00:01, 247.05it/s]
# Processing GEN:  88% 3361/3807 [00:13<00:01, 247.23it/s]
# Processing GEN:  89% 3386/3807 [00:13<00:01, 247.32it/s]
# Processing GEN:  90% 3411/3807 [00:13<00:01, 246.47it/s]
# Processing GEN:  90% 3436/3807 [00:13<00:01, 246.84it/s]
# Processing GEN:  91% 3461/3807 [00:13<00:01, 246.58it/s]
# Processing GEN:  92% 3486/3807 [00:13<00:01, 246.11it/s]
# Processing GEN:  92% 3511/3807 [00:14<00:01, 245.77it/s]
# Processing GEN:  93% 3536/3807 [00:14<00:01, 246.12it/s]
# Processing GEN:  94% 3561/3807 [00:14<00:00, 246.40it/s]
# Processing GEN:  94% 3586/3807 [00:14<00:00, 246.86it/s]
# Processing GEN:  95% 3611/3807 [00:14<00:00, 245.83it/s]
# Processing GEN:  96% 3636/3807 [00:14<00:00, 246.11it/s]
# Processing GEN:  96% 3661/3807 [00:14<00:00, 246.53it/s]
# Processing GEN:  97% 3686/3807 [00:14<00:00, 247.25it/s]
# Processing GEN:  97% 3711/3807 [00:14<00:00, 247.51it/s]
# Processing GEN:  98% 3736/3807 [00:14<00:00, 246.67it/s]
# Processing GEN:  99% 3762/3807 [00:15<00:00, 248.23it/s]
# Processing GEN: 100% 3807/3807 [00:15<00:00, 249.28it/s]
# Converting generated to 3D World Coords: 100% 1/1 [00:15<00:00, 15.27s/it]
#
# --- PHASE 4: EVALUATION ---
#
# Processing dataset: thesis/data/processed/JointModel-MLP-Baseline/h36m/ground_truth_3d_world.npz
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/JointModel-MLP-Baseline/evaluation/gt_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/JointModel-MLP-Baseline/h36m/gt_heel_strikes.json
#
# Processing dataset: thesis/data/processed/JointModel-MLP-Baseline/h36m/generated_3d_world.npz
#   Warning: Sequence 'GEN__gen_2072' too short or no heel strikes detected (T=60, peaks=1). Returning NaN metrics.
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/JointModel-MLP-Baseline/evaluation/gen_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/JointModel-MLP-Baseline/h36m/gen_heel_strikes.json
#
# --- SMPL SO(3) Evaluation ---
# Evaluated 3807 matching sequences.
#
# Overall Category Means (radians):
#   -> Overall             : 0.037208 rad
#   -> Lower Body          : 0.060163 rad
#   -> Upper Body          : 0.023434 rad
#   -> Hips                : 0.065370 rad
#   -> Knees               : 0.110107 rad
#   -> Ankles              : 0.053504 rad
#   -> Shoulders           : 0.035833 rad
#   -> Left Body           : 0.042242 rad
#   -> Right Body          : 0.042619 rad
#
# Saved detailed MPJAE evaluation results to: thesis/data/processed/JointModel-MLP-Baseline/evaluation/smpl_mpjae_evaluation.json
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading wandb-summary.json 322B/322B (0.4s)
# wandb: ⣻ uploading config.yaml 4.3KB/4.3KB (0.4s)
# wandb: ⣽ uploading wandb-summary.json 322B/322B (0.4s)
# wandb: ⣽ uploading config.yaml 4.3KB/4.3KB (0.4s)
# wandb: ⣾ uploading wandb-summary.json 322B/322B (0.4s)
# wandb: ⣾ uploading config.yaml 4.3KB/4.3KB (0.4s)
# wandb: ⣷ uploading wandb-summary.json 322B/322B (0.4s)
# wandb: ⣷ uploading config.yaml 4.3KB/4.3KB (0.4s)
# wandb: ⣯ uploading wandb-summary.json 322B/322B (0.4s)
# wandb: ⣯ uploading config.yaml 4.3KB/4.3KB (0.4s)
# wandb: ⣟ uploading wandb-summary.json 322B/322B (0.9s)
# wandb: ⣟ uploading config.yaml 4.3KB/4.3KB (0.9s)
# wandb: ⡿ uploading wandb-summary.json 322B/322B (0.9s)
# wandb: ⡿ uploading config.yaml 4.3KB/4.3KB (0.9s)
# wandb: ⢿ uploading wandb-summary.json 322B/322B (0.9s)
# wandb: ⢿ uploading config.yaml 4.3KB/4.3KB (0.9s)
# wandb: ⣻ uploading wandb-summary.json 322B/322B (0.9s)
# wandb: ⣻ uploading config.yaml 4.3KB/4.3KB (0.9s)
# wandb: ⣽ uploading wandb-summary.json 322B/322B (0.9s)
# wandb: ⣽ uploading config.yaml 4.3KB/4.3KB (0.9s)
# wandb: ⣾ uploading summary, console lines 95-113 (0.1s)
# wandb: ⣷ uploading summary, console lines 95-113 (0.1s)
# wandb:
# wandb: Run history:
# wandb:               epoch ▁▁▁▂▂▂▂▂▂▂▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇██████
# wandb:    train/loss_label ██▇█▇▆▆▆▆▅▄▄▄▃▃▃▃▃▃▂▂▂▂▃▂▂▂▂▁▂▂▂▁▂▁▂▂▁▁▁
# wandb:   train/loss_motion █▄▄▅▄▃▃▂▂▃▂▁▂▂▂▃▃▃▄▄▃▄▄▃▄▄▃▄▅▄▄▄▄▄▅▅▅▆▅▆
# wandb:    train/loss_total ███▇▇▆▆▆▅▅▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▂▁▁▂▁▁▁▁▁▁
# wandb: trainer/global_step ▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇█████
# wandb:  val/label_accuracy █▁▄▄▃▂▂▂▅▅▁▂▅▆▄
# wandb:       val/mpjae_rad ▁▂▁▃▄▅▅▅▆▅▅▇▇██
# wandb:
# wandb: Run summary:
# wandb:               epoch 149
# wandb:    train/loss_label 0.10711
# wandb:   train/loss_motion 0.03203
# wandb:    train/loss_total 0.13914
# wandb: trainer/global_step 54899
# wandb:  val/label_accuracy 0.55634
# wandb:       val/mpjae_rad 0.19935
# wandb:
# wandb: 🚀 View run JointModel-MLP-Baseline at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/y34i6gc9
# wandb: ⭐️ View project at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: thesis/data/processed/JointModel-MLP-Baseline/wandb/run-20260811_112857-y34i6gc9/logs
#
# Pipeline Finished Successfully!
