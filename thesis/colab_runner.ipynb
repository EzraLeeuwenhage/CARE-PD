# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
from pathlib import Path

zip_path = Path("/content/drive/MyDrive/CARE-PD/code.zip")
target_dir = Path("/content/drive/MyDrive/CARE-PD/thesis")

target_dir.mkdir(parents=True, exist_ok=True)

if not zip_path.exists():
    raise FileNotFoundError(f"Could not find '{zip_path}'.")

print(f"Unpacking '{zip_path}' into '{target_dir}'...")
shutil.unpack_archive(zip_path, extract_dir=target_dir)

print("Unpacking complete!")
# Out:
# Unpacking '/content/drive/MyDrive/CARE-PD/code.zip' into '/content/drive/MyDrive/CARE-PD/thesis'...
# Unpacking complete!

# %%
# !pip install -q uv

import os
os.chdir("/content/drive/MyDrive/CARE-PD")

# !uv pip compile pyproject.toml -o /tmp/reqs.txt
# !uv pip install --system -r /tmp/reqs.txt
# Out:
# Resolved 102 packages in 2.17s
# # This file was autogenerated by uv via the following command:
# #    uv pip compile pyproject.toml -o /tmp/reqs.txt
# aiohappyeyeballs==2.7.1
#     # via aiohttp
# aiohttp==3.14.3
#     # via torch-geometric
# aiosignal==1.4.0
#     # via aiohttp
# alembic==1.18.5
#     # via optuna
# annotated-types==0.8.0
#     # via pydantic
# anyio==4.14.2
#     # via httpx
# attrs==26.1.0
#     # via aiohttp
# beautifulsoup4==4.15.0
#     # via
#     #   gdown
#     #   google
# certifi==2026.7.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
#     #   sentry-sdk
# charset-normalizer==3.4.9
#     # via requests
# chumpy==0.70
#     # via care-pd (pyproject.toml)
# click==8.4.2
#     # via
#     #   huggingface-hub
#     #   wandb
# colorlog==6.12.0
#     # via optuna
# contourpy==1.3.3
#     # via matplotlib
# cuda-bindings==13.3.1
#     # via torch
# cuda-pathfinder==1.6.0
#     # via cuda-bindings
# cuda-toolkit==13.0.2
#     # via torch
# cycler==0.12.1
#     # via matplotlib
# einops==0.8.1
#     # via care-pd (pyproject.toml)
# filelock==3.32.2
#     # via
#     #   gdown
#     #   huggingface-hub
#     #   torch
# fonttools==4.63.0
#     # via matplotlib
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.7.0
#     # via
#     #   huggingface-hub
#     #   torch
#     #   torch-geometric
# gdown==6.1.0
#     # via care-pd (pyproject.toml)
# google==3.0.0
#     # via care-pd (pyproject.toml)
# greenlet==3.1.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   sqlalchemy
# h11==0.16.0
#     # via httpcore
# hf-xet==1.5.2
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via huggingface-hub
# huggingface-hub==1.25.1
#     # via timm
# idna==3.18
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# imageio==2.31.5
#     # via care-pd (pyproject.toml)
# jinja2==3.1.6
#     # via
#     #   torch
#     #   torch-geometric
# joblib==1.4.2
#     # via
#     #   care-pd (pyproject.toml)
#     #   scikit-learn
# kiwisolver==1.5.0
#     # via matplotlib
# mako==1.3.12
#     # via alembic
# markupsafe==3.0.3
#     # via
#     #   jinja2
#     #   mako
# matplotlib==3.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# mpmath==1.3.0
#     # via sympy
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# networkx==3.6.1
#     # via torch
# numpy==1.26.4
#     # via
#     #   care-pd (pyproject.toml)
#     #   contourpy
#     #   imageio
#     #   matplotlib
#     #   numpyencoder
#     #   optuna
#     #   pandas
#     #   scikit-learn
#     #   scipy
#     #   seaborn
#     #   smplx
#     #   torch-geometric
#     #   torchvision
#     #   trimesh
# numpyencoder==0.3.0
#     # via care-pd (pyproject.toml)
# nvidia-cublas==13.1.1.3
#     # via
#     #   nvidia-cudnn-cu13
#     #   nvidia-cusolver
#     #   torch
# nvidia-cuda-cupti==13.0.85
#     # via cuda-toolkit
# nvidia-cuda-nvrtc==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cublas
# nvidia-cuda-runtime==13.0.96
#     # via cuda-toolkit
# nvidia-cudnn-cu13==9.20.0.48
#     # via torch
# nvidia-cufft==12.0.0.61
#     # via cuda-toolkit
# nvidia-cufile==1.15.1.6
#     # via cuda-toolkit
# nvidia-curand==10.4.0.35
#     # via cuda-toolkit
# nvidia-cusolver==12.0.4.66
#     # via cuda-toolkit
# nvidia-cusparse==12.6.3.3
#     # via
#     #   cuda-toolkit
#     #   nvidia-cusolver
# nvidia-cusparselt-cu13==0.8.1
#     # via torch
# nvidia-nccl-cu13==2.29.7
#     # via torch
# nvidia-nvjitlink==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cufft
#     #   nvidia-cusolver
#     #   nvidia-cusparse
# nvidia-nvshmem-cu13==3.4.5
#     # via torch
# nvidia-nvtx==13.0.85
#     # via cuda-toolkit
# optuna==4.2.1
#     # via care-pd (pyproject.toml)
# packaging==26.2
#     # via
#     #   huggingface-hub
#     #   matplotlib
#     #   optuna
#     #   wandb
# pandas==2.2.3
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# pillow==12.3.0
#     # via
#     #   imageio
#     #   matplotlib
#     #   torchvision
# platformdirs==4.11.0
#     # via wandb
# propcache==0.5.2
#     # via
#     #   aiohttp
#     #   yarl
# protobuf==7.35.1
#     # via wandb
# psutil==7.2.2
#     # via torch-geometric
# pydantic==2.13.4
#     # via wandb
# pydantic-core==2.46.4
#     # via pydantic
# pyparsing==3.3.2
#     # via
#     #   matplotlib
#     #   torch-geometric
# pysocks==1.7.1
#     # via requests
# python-dateutil==2.9.0.post0
#     # via
#     #   matplotlib
#     #   pandas
# pytz==2026.3.post1
#     # via pandas
# pyyaml==6.0.3
#     # via
#     #   huggingface-hub
#     #   optuna
#     #   timm
#     #   wandb
# requests==2.34.2
#     # via
#     #   gdown
#     #   torch-geometric
#     #   wandb
# safetensors==0.8.0
#     # via timm
# scikit-learn==1.6.1
#     # via care-pd (pyproject.toml)
# scipy==1.17.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   chumpy
#     #   scikit-learn
# seaborn==0.13.2
#     # via care-pd (pyproject.toml)
# sentry-sdk==2.66.1
#     # via wandb
# setuptools==75.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   torch
# six==1.17.0
#     # via
#     #   chumpy
#     #   python-dateutil
# smplx==0.1.28
#     # via care-pd (pyproject.toml)
# soupsieve==2.9.1
#     # via beautifulsoup4
# sqlalchemy==2.0.51
#     # via
#     #   alembic
#     #   optuna
# sympy==1.14.0
#     # via torch
# threadpoolctl==3.6.0
#     # via scikit-learn
# timm==1.0.15
#     # via care-pd (pyproject.toml)
# torch==2.12.1
#     # via
#     #   smplx
#     #   timm
#     #   torch-dct
#     #   torchvision
# torch-dct==0.1.6
#     # via care-pd (pyproject.toml)
# torch-geometric==2.8.0.post1
#     # via care-pd (pyproject.toml)
# torchvision==0.27.1
#     # via timm
# tqdm==4.66.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   gdown
#     #   huggingface-hub
#     #   optuna
#     #   torch-geometric
# trimesh==4.6.8
#     # via care-pd (pyproject.toml)
# triton==3.7.1
#     # via torch
# typing-extensions==4.16.0
#     # via
#     #   aiohttp
#     #   aiosignal
#     #   alembic
#     #   anyio
#     #   beautifulsoup4
#     #   huggingface-hub
#     #   pydantic
#     #   pydantic-core
#     #   sqlalchemy
#     #   torch
#     #   typing-inspection
#     #   wandb
# typing-inspection==0.4.2
#     # via pydantic
# tzdata==2026.3
#     # via pandas
# urllib3==2.7.0
#     # via
#     #   requests
#     #   sentry-sdk
# wandb==0.28.1
#     # via care-pd (pyproject.toml)
# xxhash==3.8.1
#     # via torch-geometric
# yarl==1.24.5
#     # via aiohttp
# Using Python 3.12.13 environment at: /usr
# Resolved 102 packages in 51ms
# Prepared 62 packages in 55.73s
# Uninstalled 37 packages in 901ms
# Installed 62 packages in 564ms
#  - aiohttp==3.14.1
#  + aiohttp==3.14.3
#  + alembic==1.18.5
#  - annotated-types==0.7.0
#  + annotated-types==0.8.0
#  - beautifulsoup4==4.13.5
#  + beautifulsoup4==4.15.0
#  - certifi==2026.6.17
#  + certifi==2026.7.22
#  + chumpy==0.70
#  + colorlog==6.12.0
#  - cuda-bindings==12.9.7
#  + cuda-bindings==13.3.1
#  - cuda-pathfinder==1.5.6
#  + cuda-pathfinder==1.6.0
#  - cuda-toolkit==12.8.1
#  + cuda-toolkit==13.0.2
#  - einops==0.8.2
#  + einops==0.8.1
#  - filelock==3.29.7
#  + filelock==3.32.2
#  - fsspec==2025.3.0
#  + fsspec==2026.7.0
#  - gdown==5.2.2
#  + gdown==6.1.0
#  - greenlet==3.5.3
#  + greenlet==3.1.1
#  - hf-xet==1.5.1
#  + hf-xet==1.5.2
#  - huggingface-hub==1.23.0
#  + huggingface-hub==1.25.1
#  - imageio==2.37.3
#  + imageio==2.31.5
#  - joblib==1.5.3
#  + joblib==1.4.2
#  + mako==1.3.12
#  - matplotlib==3.10.0
#  + matplotlib==3.8.0
#  - numpy==2.0.2
#  + numpy==1.26.4
#  + numpyencoder==0.3.0
#  + nvidia-cublas==13.1.1.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.20.0.48
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.1
#  + nvidia-nccl-cu13==2.29.7
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  + optuna==4.2.1
#  - pandas==2.2.2
#  + pandas==2.2.3
#  - pillow==11.3.0
#  + pillow==12.3.0
#  - platformdirs==4.10.0
#  + platformdirs==4.11.0
#  - protobuf==5.29.6
#  + protobuf==7.35.1
#  - psutil==5.9.5
#  + psutil==7.2.2
#  - pytz==2025.2
#  + pytz==2026.3.post1
#  - requests==2.32.4
#  + requests==2.34.2
#  - scipy==1.16.3
#  + scipy==1.17.1
#  - sentry-sdk==2.65.0
#  + sentry-sdk==2.66.1
#  - setuptools==75.2.0
#  + setuptools==75.8.0
#  + smplx==0.1.28
#  - soupsieve==2.8.4
#  + soupsieve==2.9.1
#  - timm==1.0.28
#  + timm==1.0.15
#  - torch==2.11.0+cu128
#  + torch==2.12.1
#  + torch-dct==0.1.6
#  + torch-geometric==2.8.0.post1
#  - torchvision==0.26.0+cu128
#  + torchvision==0.27.1
#  - tqdm==4.67.3
#  + tqdm==4.66.1
#  + trimesh==4.6.8
#  - triton==3.6.0
#  + triton==3.7.1
#  - urllib3==2.5.0
#  + urllib3==2.7.0
#  - wandb==0.28.0
#  + wandb==0.28.1
#  - yarl==1.24.2
#  + yarl==1.24.5

# %%
drive.mount('/content/drive')
# !python -m thesis.src.run_pipeline
# Out:
# Initializing Unified Pipeline on: CUDA
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,876
#   Class 1    | 445 / 635                  |      4,878
#   Class 2    | 172 / 245                  |      2,934
#   Class 3    | 3 / 5                      |         33
# -----------------------------------------------------------------
#  TOTAL      | 1167 / 1666                |     11,721
#   * Filtered out 590 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
# EVAL SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 78 / 781                   |        630
#   Class 1    | 63 / 635                   |        876
#   Class 2    | 24 / 245                   |        463
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 166 / 1666                 |      1,979
#   * Filtered out 591 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
# TEST SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 156 / 781                  |      1,289
#   Class 1    | 127 / 635                  |      1,401
#   Class 2    | 49 / 245                   |      1,107
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 333 / 1666                 |      3,807
#   * Filtered out 63 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# --- PHASE 1: TRAINING ---
# Training on device: cuda
# Epoch 0005/100 | Train Loss: 0.010105
# Epoch 0010/100 | Train Loss: 0.008837 | Eval MPJAE: 0.1518 rad
# Epoch 0015/100 | Train Loss: 0.008347
# Epoch 0020/100 | Train Loss: 0.008047 | Eval MPJAE: 0.1470 rad
# Epoch 0025/100 | Train Loss: 0.007699
# Epoch 0030/100 | Train Loss: 0.007575 | Eval MPJAE: 0.1441 rad
# Epoch 0035/100 | Train Loss: 0.007389
# Epoch 0040/100 | Train Loss: 0.007214 | Eval MPJAE: 0.1381 rad
# Epoch 0045/100 | Train Loss: 0.006968
# Epoch 0050/100 | Train Loss: 0.006818 | Eval MPJAE: 0.1370 rad
# Epoch 0055/100 | Train Loss: 0.006849
# Epoch 0060/100 | Train Loss: 0.006798 | Eval MPJAE: 0.1463 rad
# Epoch 0065/100 | Train Loss: 0.006721
# Epoch 0070/100 | Train Loss: 0.006774 | Eval MPJAE: 0.1383 rad
# Epoch 0075/100 | Train Loss: 0.006510
# Epoch 0080/100 | Train Loss: 0.006495 | Eval MPJAE: 0.1436 rad
# Epoch 0085/100 | Train Loss: 0.006480
# Epoch 0090/100 | Train Loss: 0.006464 | Eval MPJAE: 0.1374 rad
# Epoch 0095/100 | Train Loss: 0.006414
# Epoch 0100/100 | Train Loss: 0.006369 | Eval MPJAE: 0.1369 rad
#
# Training complete. Model saved to thesis/models/baseline_model_v2.pth
#
# --- PHASE 2: DATASET GENERATION ---
#
# --- PHASE 3: FORMAT CONVERSION ---
# Formatting and caching raw 6D sequences...
# Formatting Ground Truth to SMPL...
# Saved generated SMPL data to: thesis/data/processed/baseline_model_v2/SMPL/ground_truth.pkl
# Converting Ground Truth SMPL -> H36M (This takes a moment)...
# Input Data: thesis/data/processed/baseline_model_v2/SMPL/ground_truth.pkl
# Output Dir: thesis/data/processed/baseline_model_v2/h36m
# /usr/local/lib/python3.12/dist-packages/chumpy/ch_ops.py:85: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   assert(order is 'C' or order is None)
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Converting ground_truth to 3D World Coords:   0% 0/1 [00:00<?, ?it/s]
# Processing GT:   0% 0/3807 [00:00<?, ?it/s]
# Processing GT:   0% 4/3807 [00:00<01:38, 38.65it/s]
# Processing GT:   1% 21/3807 [00:00<00:33, 113.93it/s]
# Processing GT:   1% 39/3807 [00:00<00:26, 141.76it/s]
# Processing GT:   2% 60/3807 [00:00<00:22, 167.74it/s]
# Processing GT:   2% 82/3807 [00:00<00:20, 184.28it/s]
# Processing GT:   3% 106/3807 [00:00<00:18, 200.68it/s]
# Processing GT:   3% 131/3807 [00:00<00:17, 214.09it/s]
# Processing GT:   4% 154/3807 [00:00<00:16, 216.66it/s]
# Processing GT:   5% 177/3807 [00:00<00:16, 220.51it/s]
# Processing GT:   5% 202/3807 [00:01<00:15, 227.05it/s]
# Processing GT:   6% 227/3807 [00:01<00:15, 231.28it/s]
# Processing GT:   7% 251/3807 [00:01<00:15, 229.91it/s]
# Processing GT:   7% 275/3807 [00:01<00:15, 232.85it/s]
# Processing GT:   8% 300/3807 [00:01<00:14, 235.49it/s]
# Processing GT:   9% 324/3807 [00:01<00:14, 235.42it/s]
# Processing GT:   9% 349/3807 [00:01<00:14, 236.99it/s]
# Processing GT:  10% 373/3807 [00:01<00:14, 237.32it/s]
# Processing GT:  10% 397/3807 [00:01<00:14, 231.51it/s]
# Processing GT:  11% 421/3807 [00:01<00:14, 232.55it/s]
# Processing GT:  88% 3368/3807 [00:15<00:01, 228.29it/s]
# Processing GT:  89% 3392/3807 [00:15<00:01, 230.10it/s]
# Processing GT:  90% 3416/3807 [00:15<00:01, 231.42it/s]
# Processing GT:  90% 3440/3807 [00:15<00:01, 233.12it/s]
# Processing GT:  91% 3464/3807 [00:16<00:01, 228.48it/s]
# Processing GT:  92% 3488/3807 [00:16<00:01, 230.47it/s]
# Processing GT:  92% 3512/3807 [00:16<00:01, 232.12it/s]
# Processing GT:  93% 3536/3807 [00:16<00:01, 232.14it/s]
# Processing GT:  94% 3560/3807 [00:16<00:01, 223.75it/s]
# Processing GT:  94% 3583/3807 [00:16<00:01, 219.03it/s]
# Processing GT:  95% 3607/3807 [00:16<00:00, 223.81it/s]
# Processing GT:  95% 3631/3807 [00:16<00:00, 226.22it/s]
# Processing GT:  96% 3655/3807 [00:16<00:00, 228.18it/s]
# Processing GT:  97% 3679/3807 [00:16<00:00, 231.23it/s]
# Processing GT:  97% 3703/3807 [00:17<00:00, 231.61it/s]
# Processing GT:  98% 3727/3807 [00:17<00:00, 233.31it/s]
# Processing GT:  99% 3751/3807 [00:17<00:00, 231.02it/s]
# Processing GT:  99% 3775/3807 [00:17<00:00, 232.52it/s]
# Processing GT: 100% 3807/3807 [00:17<00:00, 217.15it/s]
# Converting ground_truth to 3D World Coords: 100% 1/1 [00:17<00:00, 17.53s/it]
# Formatting Generated data to SMPL...
# Saved generated SMPL data to: thesis/data/processed/baseline_model_v2/SMPL/generated.pkl
# Converting Generated SMPL -> H36M...
# Input Data: thesis/data/processed/baseline_model_v2/SMPL/generated.pkl
# Output Dir: thesis/data/processed/baseline_model_v2/h36m
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Converting generated to 3D World Coords:   0% 0/1 [00:00<?, ?it/s]
# Processing GEN:   0% 0/3807 [00:00<?, ?it/s]
# Processing GEN:   0% 15/3807 [00:00<00:25, 149.65it/s]
# Processing GEN:   1% 30/3807 [00:00<00:25, 149.74it/s]
# Processing GEN:   1% 45/3807 [00:00<00:26, 143.37it/s]
# Processing GEN:   2% 63/3807 [00:00<00:24, 155.68it/s]
# Processing GEN:   2% 81/3807 [00:00<00:22, 162.01it/s]
# Processing GEN:   3% 101/3807 [00:00<00:21, 173.61it/s]
# Processing GEN:   3% 120/3807 [00:00<00:20, 178.41it/s]
# Processing GEN:   4% 141/3807 [00:00<00:19, 187.06it/s]
# Processing GEN:   4% 160/3807 [00:00<00:19, 184.58it/s]
# Processing GEN:   5% 181/3807 [00:01<00:19, 189.96it/s]
# Processing GEN:   5% 201/3807 [00:01<00:18, 192.63it/s]
# Processing GEN:   6% 222/3807 [00:01<00:18, 196.98it/s]
# Processing GEN:   6% 242/3807 [00:01<00:19, 186.81it/s]
# Processing GEN:   7% 261/3807 [00:01<00:20, 173.90it/s]
# Processing GEN:   7% 279/3807 [00:01<00:20, 171.38it/s]
# Processing GEN:   8% 297/3807 [00:01<00:20, 172.86it/s]
# Processing GEN:  84% 3213/3807 [00:14<00:03, 180.83it/s]
# Processing GEN:  85% 3232/3807 [00:15<00:03, 176.65it/s]
# Processing GEN:  85% 3251/3807 [00:15<00:03, 177.18it/s]
# Processing GEN:  86% 3271/3807 [00:15<00:02, 182.44it/s]
# Processing GEN:  87% 3295/3807 [00:15<00:02, 197.95it/s]
# Processing GEN:  87% 3319/3807 [00:15<00:02, 209.13it/s]
# Processing GEN:  88% 3343/3807 [00:15<00:02, 217.38it/s]
# Processing GEN:  88% 3367/3807 [00:15<00:01, 222.25it/s]
# Processing GEN:  89% 3391/3807 [00:15<00:01, 227.27it/s]
# Processing GEN:  90% 3415/3807 [00:15<00:01, 229.38it/s]
# Processing GEN:  90% 3439/3807 [00:15<00:01, 229.72it/s]
# Processing GEN:  91% 3463/3807 [00:16<00:01, 225.24it/s]
# Processing GEN:  92% 3487/3807 [00:16<00:01, 228.25it/s]
# Processing GEN:  92% 3511/3807 [00:16<00:01, 231.54it/s]
# Processing GEN:  93% 3535/3807 [00:16<00:01, 233.56it/s]
# Processing GEN:  93% 3559/3807 [00:16<00:01, 231.10it/s]
# Processing GEN:  94% 3583/3807 [00:16<00:00, 232.11it/s]
# Processing GEN:  95% 3607/3807 [00:16<00:00, 233.94it/s]
# Processing GEN:  95% 3631/3807 [00:16<00:00, 234.23it/s]
# Processing GEN:  96% 3655/3807 [00:16<00:00, 235.29it/s]
# Processing GEN:  97% 3679/3807 [00:17<00:00, 232.63it/s]
# Processing GEN:  97% 3703/3807 [00:17<00:00, 220.94it/s]
# Processing GEN:  98% 3726/3807 [00:17<00:00, 222.08it/s]
# Processing GEN:  98% 3749/3807 [00:17<00:00, 223.52it/s]
# Processing GEN:  99% 3772/3807 [00:17<00:00, 221.67it/s]
# Processing GEN: 100% 3807/3807 [00:17<00:00, 216.18it/s]
# Converting generated to 3D World Coords: 100% 1/1 [00:17<00:00, 17.61s/it]
#
# --- PHASE 4: EVALUATION ---
#
# Processing dataset: thesis/data/processed/baseline_model_v2/h36m/ground_truth_3d_world.npz
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/baseline_model_v2/evaluation/gt_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/baseline_model_v2/h36m/heel_strikes.json
#
# Processing dataset: thesis/data/processed/baseline_model_v2/h36m/generated_3d_world.npz
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/baseline_model_v2/evaluation/gen_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/baseline_model_v2/h36m/heel_strikes.json
#
# --- SMPL SO(3) Evaluation ---
# Evaluated 3807 matching sequences.
#
# Overall Category Means (radians):
#   -> Overall             : 0.028295 rad
#   -> Lower Body          : 0.043733 rad
#   -> Upper Body          : 0.019032 rad
#   -> Hips                : 0.046502 rad
#   -> Knees               : 0.076220 rad
#   -> Ankles & Feet       : 0.030369 rad
#   -> Shoulders & Collars : 0.024294 rad
#   -> Left Body           : 0.031957 rad
#   -> Right Body          : 0.032073 rad
#
# Saved detailed MPJAE evaluation results to: thesis/data/processed/baseline_model_v2/evaluation/smpl_mpjae_evaluation.json
#
# Pipeline Finished Successfully!
