# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
from pathlib import Path

zip_path = Path("/content/drive/MyDrive/CARE-PD/code.zip")
target_dir = Path("/content/drive/MyDrive/CARE-PD/thesis")

target_dir.mkdir(parents=True, exist_ok=True)

if not zip_path.exists():
    raise FileNotFoundError(f"Could not find '{zip_path}'.")

print(f"Unpacking '{zip_path}' into '{target_dir}'...")
shutil.unpack_archive(zip_path, extract_dir=target_dir)

print("Unpacking complete!")
# Out:
# Unpacking '/content/drive/MyDrive/CARE-PD/code.zip' into '/content/drive/MyDrive/CARE-PD/thesis'...
# Unpacking complete!

# %%
# !pip install -q uv

import os
os.chdir("/content/drive/MyDrive/CARE-PD")

# !uv pip compile pyproject.toml -o /tmp/reqs.txt
# !uv pip install --system -r /tmp/reqs.txt
# Out:
# Resolved 107 packages in 197ms
# # This file was autogenerated by uv via the following command:
# #    uv pip compile pyproject.toml -o /tmp/reqs.txt
# aiohappyeyeballs==2.7.1
#     # via aiohttp
# aiohttp==3.14.3
#     # via
#     #   fsspec
#     #   torch-geometric
# aiosignal==1.4.0
#     # via aiohttp
# alembic==1.19.2
#     # via optuna
# annotated-types==0.8.0
#     # via pydantic
# anyio==4.15.1
#     # via httpx
# attrs==26.1.0
#     # via aiohttp
# beautifulsoup4==4.15.0
#     # via
#     #   gdown
#     #   google
# certifi==2026.7.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
#     #   sentry-sdk
# charset-normalizer==3.5.1
#     # via requests
# chumpy==0.70
#     # via care-pd (pyproject.toml)
# click==8.5.0
#     # via
#     #   huggingface-hub
#     #   wandb
# colorlog==6.12.0
#     # via optuna
# contourpy==1.3.3
#     # via matplotlib
# cuda-bindings==13.3.1
#     # via torch
# cuda-pathfinder==1.8.1
#     # via cuda-bindings
# cuda-toolkit==13.0.2
#     # via torch
# cycler==0.12.1
#     # via matplotlib
# einops==0.8.1
#     # via care-pd (pyproject.toml)
# filelock==3.32.5
#     # via
#     #   gdown
#     #   huggingface-hub
#     #   torch
# fonttools==4.64.0
#     # via matplotlib
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.7.0
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   pytorch-lightning
#     #   torch
#     #   torch-geometric
# gdown==6.2.0
#     # via care-pd (pyproject.toml)
# google==3.0.0
#     # via care-pd (pyproject.toml)
# greenlet==3.1.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   sqlalchemy
# h11==0.16.0
#     # via httpcore
# hf-xet==1.6.0
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via huggingface-hub
# huggingface-hub==1.30.0
#     # via timm
# idna==3.19
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# imageio==2.31.5
#     # via care-pd (pyproject.toml)
# jinja2==3.1.6
#     # via
#     #   torch
#     #   torch-geometric
# joblib==1.4.2
#     # via
#     #   care-pd (pyproject.toml)
#     #   scikit-learn
# kiwisolver==1.5.1
#     # via matplotlib
# lightning==2.6.5
#     # via care-pd (pyproject.toml)
# lightning-utilities==0.15.3
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   torchmetrics
# mako==1.4.1
#     # via alembic
# markupsafe==3.0.3
#     # via
#     #   jinja2
#     #   mako
# matplotlib==3.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# mpmath==1.3.0
#     # via sympy
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# networkx==3.6.1
#     # via torch
# numpy==1.26.4
#     # via
#     #   care-pd (pyproject.toml)
#     #   contourpy
#     #   imageio
#     #   matplotlib
#     #   numpyencoder
#     #   optuna
#     #   pandas
#     #   scikit-learn
#     #   scipy
#     #   seaborn
#     #   smplx
#     #   torch-geometric
#     #   torchmetrics
#     #   torchvision
#     #   trimesh
# numpyencoder==0.3.0
#     # via care-pd (pyproject.toml)
# nvidia-cublas==13.1.1.3
#     # via
#     #   nvidia-cudnn-cu13
#     #   nvidia-cusolver
#     #   torch
# nvidia-cuda-cupti==13.0.85
#     # via cuda-toolkit
# nvidia-cuda-nvrtc==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cublas
# nvidia-cuda-runtime==13.0.96
#     # via cuda-toolkit
# nvidia-cudnn-cu13==9.20.0.48
#     # via torch
# nvidia-cufft==12.0.0.61
#     # via cuda-toolkit
# nvidia-cufile==1.15.1.6
#     # via cuda-toolkit
# nvidia-curand==10.4.0.35
#     # via cuda-toolkit
# nvidia-cusolver==12.0.4.66
#     # via cuda-toolkit
# nvidia-cusparse==12.6.3.3
#     # via
#     #   cuda-toolkit
#     #   nvidia-cusolver
# nvidia-cusparselt-cu13==0.8.1
#     # via torch
# nvidia-nccl-cu13==2.29.7
#     # via torch
# nvidia-nvjitlink==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cufft
#     #   nvidia-cusolver
#     #   nvidia-cusparse
# nvidia-nvshmem-cu13==3.4.5
#     # via torch
# nvidia-nvtx==13.0.85
#     # via cuda-toolkit
# opentelemetry-api==1.44.0
#     # via wandb
# optuna==4.2.1
#     # via care-pd (pyproject.toml)
# packaging==26.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   matplotlib
#     #   optuna
#     #   pytorch-lightning
#     #   torchmetrics
#     #   wandb
# pandas==2.2.3
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# pillow==12.3.0
#     # via
#     #   imageio
#     #   matplotlib
#     #   torchvision
# platformdirs==4.11.7
#     # via wandb
# propcache==0.5.2
#     # via
#     #   aiohttp
#     #   yarl
# protobuf==7.36.1
#     # via wandb
# psutil==7.2.2
#     # via torch-geometric
# pydantic==2.13.5
#     # via wandb
# pydantic-core==2.46.5
#     # via pydantic
# pyparsing==3.3.2
#     # via
#     #   matplotlib
#     #   torch-geometric
# pysocks==1.7.1
#     # via requests
# python-dateutil==2.9.0.post0
#     # via
#     #   matplotlib
#     #   pandas
# pytorch-lightning==2.6.5
#     # via lightning
# pytz==2026.3.post1
#     # via pandas
# pyyaml==6.0.3
#     # via
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   timm
#     #   wandb
# requests==2.34.2
#     # via
#     #   gdown
#     #   torch-geometric
#     #   wandb
# safetensors==0.8.0
#     # via timm
# scikit-learn==1.6.1
#     # via care-pd (pyproject.toml)
# scipy==1.17.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   chumpy
#     #   scikit-learn
# seaborn==0.13.2
#     # via care-pd (pyproject.toml)
# sentry-sdk==2.68.1
#     # via wandb
# setuptools==75.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   torch
# six==1.17.0
#     # via
#     #   chumpy
#     #   python-dateutil
# smplx==0.1.28
#     # via care-pd (pyproject.toml)
# soupsieve==2.9.2
#     # via beautifulsoup4
# sqlalchemy==2.0.52
#     # via
#     #   alembic
#     #   optuna
# sympy==1.14.0
#     # via torch
# threadpoolctl==3.6.0
#     # via scikit-learn
# timm==1.0.15
#     # via care-pd (pyproject.toml)
# torch==2.12.1
#     # via
#     #   lightning
#     #   pytorch-lightning
#     #   smplx
#     #   timm
#     #   torch-dct
#     #   torchmetrics
#     #   torchvision
# torch-dct==0.1.6
#     # via care-pd (pyproject.toml)
# torch-geometric==2.8.0.post1
#     # via care-pd (pyproject.toml)
# torchmetrics==1.9.0
#     # via
#     #   lightning
#     #   pytorch-lightning
# torchvision==0.27.1
#     # via timm
# tqdm==4.66.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   gdown
#     #   huggingface-hub
#     #   lightning
#     #   optuna
#     #   pytorch-lightning
#     #   torch-geometric
# trimesh==4.6.8
#     # via care-pd (pyproject.toml)
# triton==3.7.1
#     # via torch
# typing-extensions==4.16.0
#     # via
#     #   alembic
#     #   anyio
#     #   beautifulsoup4
#     #   huggingface-hub
#     #   lightning
#     #   lightning-utilities
#     #   opentelemetry-api
#     #   pydantic
#     #   pydantic-core
#     #   pytorch-lightning
#     #   sqlalchemy
#     #   torch
#     #   typing-inspection
#     #   wandb
# typing-inspection==0.4.4
#     # via pydantic
# tzdata==2026.3
#     # via pandas
# urllib3==2.7.0
#     # via
#     #   requests
#     #   sentry-sdk
# wandb==0.29.0
#     # via care-pd (pyproject.toml)
# xxhash==4.0.1
#     # via
#     #   torch-geometric
#     #   wandb
# yarl==1.24.5
#     # via aiohttp
# Using Python 3.13.15 environment at: /usr
# Checked 107 packages in 98ms

# %%
import wandb
wandb.login()
# Out:
# True

# %%
drive.mount('/content/drive')
# !python -m thesis.src.run_pipeline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: e-j-h-leeuwenhage (e-j-h-leeuwenhage-eindhoven-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: ⢿ setting up run p66vzpyf (0.0s)
# wandb: ⣻ setting up run p66vzpyf (0.0s)
# wandb: ⣽ setting up run p66vzpyf (0.0s)
# wandb: Tracking run with wandb version 0.29.0
# wandb: Run data is saved locally in thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb/run-20260907_115503-p66vzpyf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run test-Joint-MLP-Baseline-3D
# wandb: ⭐️ View project at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: 🚀 View run at https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/p66vzpyf
#
# Starting model train-test pipeline for 'test-Joint-MLP-Baseline-3D' (Joint Model: True)...
#
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,876
#   Class 1    | 445 / 635                  |      4,878
#   Class 2    | 172 / 245                  |      2,934
#   Class 3    | 3 / 5                      |         33
# -----------------------------------------------------------------
#  TOTAL      | 1167 / 1666                |     11,721
#   * Filtered out 590 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# EVAL SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 78 / 781                   |        630
#   Class 1    | 63 / 635                   |        876
#   Class 2    | 24 / 245                   |        463
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 166 / 1666                 |      1,979
#   * Filtered out 591 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# TEST SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 156 / 781                  |      1,289
#   Class 1    | 127 / 635                  |      1,401
#   Class 2    | 49 / 245                   |      1,107
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 333 / 1666                 |      3,807
#   * Filtered out 63 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
# --- PHASE 0: BASELINE EVALUATION ---
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
# [W&B Callback] Sampling Anchor Sequences across Severity Classes...
#   -> Locked Random Anchor for Severity Class 0
#   -> Locked Random Anchor for Severity Class 1
#   -> Locked Random Anchor for Severity Class 2
#   -> Locked Random Anchor for Severity Class 3
#
# --- [W&B Callback] Running Validation (Epoch 0) ---
#   [Time] Trajectory Generation: 1.97s
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
#   [Time] SMPL to H36M Batch Conversion: 2.92s
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [SMPLEvaluator] Processing 1979 sequences in parallel...
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_0/03e_sparc_all_24_joints.png
#   [Time] Metric Extraction & Plots: 36.71s
#   [Time] Anchor GIF Rendering: 64.21s
#   [Time] TOTAL Validation Routine: 109.33s
#
#
# --- PHASE 1: TRAINING ---
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.13/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name      ┃ Type                  ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ backbone  │ JointBaselineBackbone │  6.8 M │ train │     0 │
# │ 1 │ flow_head │ FlowHead              │  3.5 M │ train │     0 │
# │ 2 │ jump_head │ JumpHead              │  4.1 K │ train │     0 │
# └───┴───────────┴───────────────────────┴────────┴───────┴───────┘
# Trainable params: 10.3 M
# Non-trainable params: 0
# Total params: 10.3 M
# Total estimated model params size (MB): 41.211
# Modules in train mode: 14
# Modules in eval mode: 0
# Total FLOPs: 0
# Epoch 0005/150 | Train Loss: 1.4354
#  >>> VALIDATION Epoch 0010 | MPJAE: 8.33 deg | Label Acc: 0.5523
# Epoch 0010/150 | Train Loss: 1.1943
# Epoch 0015/150 | Train Loss: 1.0376
#  >>> VALIDATION Epoch 0020 | MPJAE: 7.98 deg | Label Acc: 0.5659
# Epoch 0020/150 | Train Loss: 0.9388
# Epoch 0025/150 | Train Loss: 0.8987
#  >>> VALIDATION Epoch 0030 | MPJAE: 7.99 deg | Label Acc: 0.6043
# Epoch 0030/150 | Train Loss: 0.8632
# Epoch 0035/150 | Train Loss: 0.8570
#  >>> VALIDATION Epoch 0040 | MPJAE: 7.82 deg | Label Acc: 0.5750
# Epoch 0040/150 | Train Loss: 0.8141
# Epoch 0045/150 | Train Loss: 0.7773
#  >>> VALIDATION Epoch 0050 | MPJAE: 7.81 deg | Label Acc: 0.6049
#
# --- [W&B Callback] Running Validation (Epoch 50) ---
#   [Time] Trajectory Generation: 2.07s
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
#   [Time] SMPL to H36M Batch Conversion: 2.87s
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [SMPLEvaluator] Processing 1979 sequences in parallel...
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_50/03e_sparc_all_24_joints.png
#   [Time] Metric Extraction & Plots: 31.16s
#   [Time] Anchor GIF Rendering: 64.08s
#   [Time] TOTAL Validation Routine: 102.60s
#
# Epoch 0050/150 | Train Loss: 0.7863
# Epoch 0055/150 | Train Loss: 0.7399
#  >>> VALIDATION Epoch 0060 | MPJAE: 8.34 deg | Label Acc: 0.5771
# Epoch 0060/150 | Train Loss: 0.7193
# Epoch 0065/150 | Train Loss: 0.7255
#  >>> VALIDATION Epoch 0070 | MPJAE: 7.80 deg | Label Acc: 0.5912
# Epoch 0070/150 | Train Loss: 0.7634
# Epoch 0075/150 | Train Loss: 0.6903
#  >>> VALIDATION Epoch 0080 | MPJAE: 7.83 deg | Label Acc: 0.5846
# Epoch 0080/150 | Train Loss: 0.6982
# Epoch 0085/150 | Train Loss: 0.6544
#  >>> VALIDATION Epoch 0090 | MPJAE: 7.85 deg | Label Acc: 0.5786
# Epoch 0090/150 | Train Loss: 0.6688
# Epoch 0095/150 | Train Loss: 0.7073
#  >>> VALIDATION Epoch 0100 | MPJAE: 7.72 deg | Label Acc: 0.6028
#
# --- [W&B Callback] Running Validation (Epoch 100) ---
#   [Time] Trajectory Generation: 2.27s
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
#   [Time] SMPL to H36M Batch Conversion: 2.88s
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [SMPLEvaluator] Processing 1979 sequences in parallel...
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_100/03e_sparc_all_24_joints.png
#   [Time] Metric Extraction & Plots: 31.55s
#   [Time] Anchor GIF Rendering: 63.43s
#   [Time] TOTAL Validation Routine: 102.66s
#
# Epoch 0100/150 | Train Loss: 0.6681
# Epoch 0105/150 | Train Loss: 0.6772
#  >>> VALIDATION Epoch 0110 | MPJAE: 7.70 deg | Label Acc: 0.5917
# Epoch 0110/150 | Train Loss: 0.6536
# Epoch 0115/150 | Train Loss: 0.6299
#  >>> VALIDATION Epoch 0120 | MPJAE: 7.81 deg | Label Acc: 0.5932
# Epoch 0120/150 | Train Loss: 0.6481
# Epoch 0125/150 | Train Loss: 0.6644
#  >>> VALIDATION Epoch 0130 | MPJAE: 7.80 deg | Label Acc: 0.5730
# Epoch 0130/150 | Train Loss: 0.6345
# Epoch 0135/150 | Train Loss: 0.6201
#  >>> VALIDATION Epoch 0140 | MPJAE: 7.72 deg | Label Acc: 0.5922
# Epoch 0140/150 | Train Loss: 0.6435
# Epoch 0145/150 | Train Loss: 0.6205
#  >>> VALIDATION Epoch 0150 | MPJAE: 7.68 deg | Label Acc: 0.6225
#
# --- [W&B Callback] Running Validation (Epoch 150) ---
#   [Time] Trajectory Generation: 2.24s
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
#   [Time] SMPL to H36M Batch Conversion: 2.88s
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [H36MEvaluator] Processing 1979 sequences in parallel...
#   [SMPLEvaluator] Processing 1979 sequences in parallel...
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb_eval_cache/visualizations_Epoch_150/03e_sparc_all_24_joints.png
#   [Time] Metric Extraction & Plots: 32.05s
#   [Time] Anchor GIF Rendering: 64.73s
#   [Time] TOTAL Validation Routine: 104.41s
#
# Epoch 0150/150 | Train Loss: 0.6270
# `Trainer.fit` stopped: `max_epochs=150` reached.
#
# --- PHASE 2: DATASET GENERATION ---
# Loading best checkpoint from: /content/drive/My Drive/CARE-PD/thesis/data/processed/test-Joint-MLP-Baseline-3D/checkpoints/best-epoch=149-val/mpjae_deg=7.68.ckpt
# Final Test Label Accuracy: 0.5965 (2271/3807 matches)
#
# --- PHASE 3: FINAL TEST EVALUATION & DISK STORAGE ---
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Saved Final Test Set datasets to disk at thesis/data/processed/test-Joint-MLP-Baseline-3D
#   [H36MEvaluator] Processing 3807 sequences in parallel...
#   [H36MEvaluator] Processing 3807 sequences in parallel...
#   [SMPLEvaluator] Processing 3807 sequences in parallel...
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/gt_00_dataset_summary.png
# Saved dataset summary plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/gen_00_dataset_summary.png
# Saved SMPL Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/03a_smpl_mpjae_categories.png
# Saved 24-Joint ordered breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/03b_smpl_mpjae_all_24_joints.png
# Saved Arm Swing distributions plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/03c_smpl_arm_swing_distributions.png
# Saved independent Knee Discriminators box plots to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/03f_sparc_knee_class_discriminators.png
# Saved SPARC Category breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/03d_sparc_categories.png
# Saved 24-Joint SPARC breakdown plot to: thesis/data/processed/test-Joint-MLP-Baseline-3D/visualizations_Final_Test/03e_sparc_all_24_joints.png
# wandb: WARNING Tried to log to step 54900 that is less than the current step 54902. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading summary, console lines 213-218 (0.1s)
# wandb:
# wandb: Run history:
# wandb:                               epoch ▁▁▁▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇███████
# wandb:    eval_metrics/Mean_Hellinger_H36M █▁▁▁
# wandb:    eval_metrics/Mean_Hellinger_SMPL █▂▁▃
# wandb:           eval_metrics/Mean_KS_H36M █▂▁▁
# wandb:           eval_metrics/Mean_KS_SMPL █▁▁▄
# wandb:      eval_metrics/Overall_MPJAE_deg █▁▁▁
# wandb:  physical_realism/mean_floating_gen █▂▁▁
# wandb:   physical_realism/mean_floating_gt ▁▁▁▁
# wandb: physical_realism/mean_foot_disp_gen █▂▁▁
# wandb:  physical_realism/mean_foot_disp_gt ▁▁▁▁
# wandb:                                  +6 ...
# wandb:
# wandb: Run summary:
# wandb:                               epoch 149
# wandb:    eval_metrics/Mean_Hellinger_H36M 0.4866
# wandb:    eval_metrics/Mean_Hellinger_SMPL 0.39147
# wandb:           eval_metrics/Mean_KS_H36M 0.45301
# wandb:           eval_metrics/Mean_KS_SMPL 0.46713
# wandb:      eval_metrics/Overall_MPJAE_deg 7.67622
# wandb:  physical_realism/mean_floating_gen 0.02233
# wandb:   physical_realism/mean_floating_gt 0.00117
# wandb: physical_realism/mean_foot_disp_gen 0.1522
# wandb:  physical_realism/mean_foot_disp_gt 0.06506
# wandb:                                  +6 ...
# wandb:
# wandb: 🚀 View run test-Joint-MLP-Baseline-3D at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis/runs/p66vzpyf
# wandb: ⭐️ View project at: https://wandb.ai/e-j-h-leeuwenhage-eindhoven-university-of-technology/thesis
# wandb: Synced 5 W&B file(s), 96 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: thesis/data/processed/test-Joint-MLP-Baseline-3D/wandb/run-20260907_115503-p66vzpyf/logs
#
# Pipeline Finished Successfully!
