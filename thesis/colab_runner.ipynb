# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
from pathlib import Path

zip_path = Path("/content/drive/MyDrive/CARE-PD/code.zip")
target_dir = Path("/content/drive/MyDrive/CARE-PD/thesis")

target_dir.mkdir(parents=True, exist_ok=True)

if not zip_path.exists():
    raise FileNotFoundError(f"Could not find '{zip_path}'.")

print(f"Unpacking '{zip_path}' into '{target_dir}'...")
shutil.unpack_archive(zip_path, extract_dir=target_dir)

print("Unpacking complete!")
# Out:
# Unpacking '/content/drive/MyDrive/CARE-PD/code.zip' into '/content/drive/MyDrive/CARE-PD/thesis'...
# Unpacking complete!

# %%
# !pip install -q uv

import os
os.chdir("/content/drive/MyDrive/CARE-PD")

# !uv pip compile pyproject.toml -o /tmp/reqs.txt
# !uv pip install --system -r /tmp/reqs.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.0/22.0 MB 82.9 MB/s eta 0:00:00:00:0100:01
# Resolved 102 packages in 2.12s                                       0m
# # This file was autogenerated by uv via the following command:
# #    uv pip compile pyproject.toml -o /tmp/reqs.txt
# aiohappyeyeballs==2.7.1
#     # via aiohttp
# aiohttp==3.14.3
#     # via torch-geometric
# aiosignal==1.4.0
#     # via aiohttp
# alembic==1.18.5
#     # via optuna
# annotated-types==0.8.0
#     # via pydantic
# anyio==4.14.2
#     # via httpx
# attrs==26.1.0
#     # via aiohttp
# beautifulsoup4==4.15.0
#     # via
#     #   gdown
#     #   google
# certifi==2026.7.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
#     #   sentry-sdk
# charset-normalizer==3.4.9
#     # via requests
# chumpy==0.70
#     # via care-pd (pyproject.toml)
# click==8.4.2
#     # via
#     #   huggingface-hub
#     #   wandb
# colorlog==6.12.0
#     # via optuna
# contourpy==1.3.3
#     # via matplotlib
# cuda-bindings==13.3.1
#     # via torch
# cuda-pathfinder==1.6.0
#     # via cuda-bindings
# cuda-toolkit==13.0.2
#     # via torch
# cycler==0.12.1
#     # via matplotlib
# einops==0.8.1
#     # via care-pd (pyproject.toml)
# filelock==3.32.2
#     # via
#     #   gdown
#     #   huggingface-hub
#     #   torch
# fonttools==4.63.0
#     # via matplotlib
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.7.0
#     # via
#     #   huggingface-hub
#     #   torch
#     #   torch-geometric
# gdown==6.1.0
#     # via care-pd (pyproject.toml)
# google==3.0.0
#     # via care-pd (pyproject.toml)
# greenlet==3.1.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   sqlalchemy
# h11==0.16.0
#     # via httpcore
# hf-xet==1.5.2
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via huggingface-hub
# huggingface-hub==1.26.0
#     # via timm
# idna==3.18
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# imageio==2.31.5
#     # via care-pd (pyproject.toml)
# jinja2==3.1.6
#     # via
#     #   torch
#     #   torch-geometric
# joblib==1.4.2
#     # via
#     #   care-pd (pyproject.toml)
#     #   scikit-learn
# kiwisolver==1.5.0
#     # via matplotlib
# mako==1.3.12
#     # via alembic
# markupsafe==3.0.3
#     # via
#     #   jinja2
#     #   mako
# matplotlib==3.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# mpmath==1.3.0
#     # via sympy
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# networkx==3.6.1
#     # via torch
# numpy==1.26.4
#     # via
#     #   care-pd (pyproject.toml)
#     #   contourpy
#     #   imageio
#     #   matplotlib
#     #   numpyencoder
#     #   optuna
#     #   pandas
#     #   scikit-learn
#     #   scipy
#     #   seaborn
#     #   smplx
#     #   torch-geometric
#     #   torchvision
#     #   trimesh
# numpyencoder==0.3.0
#     # via care-pd (pyproject.toml)
# nvidia-cublas==13.1.1.3
#     # via
#     #   nvidia-cudnn-cu13
#     #   nvidia-cusolver
#     #   torch
# nvidia-cuda-cupti==13.0.85
#     # via cuda-toolkit
# nvidia-cuda-nvrtc==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cublas
# nvidia-cuda-runtime==13.0.96
#     # via cuda-toolkit
# nvidia-cudnn-cu13==9.20.0.48
#     # via torch
# nvidia-cufft==12.0.0.61
#     # via cuda-toolkit
# nvidia-cufile==1.15.1.6
#     # via cuda-toolkit
# nvidia-curand==10.4.0.35
#     # via cuda-toolkit
# nvidia-cusolver==12.0.4.66
#     # via cuda-toolkit
# nvidia-cusparse==12.6.3.3
#     # via
#     #   cuda-toolkit
#     #   nvidia-cusolver
# nvidia-cusparselt-cu13==0.8.1
#     # via torch
# nvidia-nccl-cu13==2.29.7
#     # via torch
# nvidia-nvjitlink==13.0.88
#     # via
#     #   cuda-toolkit
#     #   nvidia-cufft
#     #   nvidia-cusolver
#     #   nvidia-cusparse
# nvidia-nvshmem-cu13==3.4.5
#     # via torch
# nvidia-nvtx==13.0.85
#     # via cuda-toolkit
# optuna==4.2.1
#     # via care-pd (pyproject.toml)
# packaging==26.2
#     # via
#     #   huggingface-hub
#     #   matplotlib
#     #   optuna
#     #   wandb
# pandas==2.2.3
#     # via
#     #   care-pd (pyproject.toml)
#     #   seaborn
# pillow==12.3.0
#     # via
#     #   imageio
#     #   matplotlib
#     #   torchvision
# platformdirs==4.11.0
#     # via wandb
# propcache==0.5.2
#     # via
#     #   aiohttp
#     #   yarl
# protobuf==7.35.1
#     # via wandb
# psutil==7.2.2
#     # via torch-geometric
# pydantic==2.13.4
#     # via wandb
# pydantic-core==2.46.4
#     # via pydantic
# pyparsing==3.3.2
#     # via
#     #   matplotlib
#     #   torch-geometric
# pysocks==1.7.1
#     # via requests
# python-dateutil==2.9.0.post0
#     # via
#     #   matplotlib
#     #   pandas
# pytz==2026.3.post1
#     # via pandas
# pyyaml==6.0.3
#     # via
#     #   huggingface-hub
#     #   optuna
#     #   timm
#     #   wandb
# requests==2.34.2
#     # via
#     #   gdown
#     #   torch-geometric
#     #   wandb
# safetensors==0.8.0
#     # via timm
# scikit-learn==1.6.1
#     # via care-pd (pyproject.toml)
# scipy==1.17.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   chumpy
#     #   scikit-learn
# seaborn==0.13.2
#     # via care-pd (pyproject.toml)
# sentry-sdk==2.66.1
#     # via wandb
# setuptools==75.8.0
#     # via
#     #   care-pd (pyproject.toml)
#     #   torch
# six==1.17.0
#     # via
#     #   chumpy
#     #   python-dateutil
# smplx==0.1.28
#     # via care-pd (pyproject.toml)
# soupsieve==2.9.1
#     # via beautifulsoup4
# sqlalchemy==2.0.51
#     # via
#     #   alembic
#     #   optuna
# sympy==1.14.0
#     # via torch
# threadpoolctl==3.6.0
#     # via scikit-learn
# timm==1.0.15
#     # via care-pd (pyproject.toml)
# torch==2.12.1
#     # via
#     #   smplx
#     #   timm
#     #   torch-dct
#     #   torchvision
# torch-dct==0.1.6
#     # via care-pd (pyproject.toml)
# torch-geometric==2.8.0.post1
#     # via care-pd (pyproject.toml)
# torchvision==0.27.1
#     # via timm
# tqdm==4.66.1
#     # via
#     #   care-pd (pyproject.toml)
#     #   gdown
#     #   huggingface-hub
#     #   optuna
#     #   torch-geometric
# trimesh==4.6.8
#     # via care-pd (pyproject.toml)
# triton==3.7.1
#     # via torch
# typing-extensions==4.16.0
#     # via
#     #   aiohttp
#     #   aiosignal
#     #   alembic
#     #   anyio
#     #   beautifulsoup4
#     #   huggingface-hub
#     #   pydantic
#     #   pydantic-core
#     #   sqlalchemy
#     #   torch
#     #   typing-inspection
#     #   wandb
# typing-inspection==0.4.2
#     # via pydantic
# tzdata==2026.3
#     # via pandas
# urllib3==2.7.0
#     # via
#     #   requests
#     #   sentry-sdk
# wandb==0.28.1
#     # via care-pd (pyproject.toml)
# xxhash==3.8.1
#     # via torch-geometric
# yarl==1.24.5
#     # via aiohttp
# Using Python 3.12.13 environment at: /usr
# Resolved 102 packages in 33ms
# Prepared 62 packages in 51.32s
# Uninstalled 37 packages in 1.03s
# Installed 62 packages in 226ms
#  - aiohttp==3.14.1
#  + aiohttp==3.14.3
#  + alembic==1.18.5
#  - annotated-types==0.7.0
#  + annotated-types==0.8.0
#  - beautifulsoup4==4.13.5
#  + beautifulsoup4==4.15.0
#  - certifi==2026.6.17
#  + certifi==2026.7.22
#  + chumpy==0.70
#  + colorlog==6.12.0
#  - cuda-bindings==12.9.7
#  + cuda-bindings==13.3.1
#  - cuda-pathfinder==1.5.6
#  + cuda-pathfinder==1.6.0
#  - cuda-toolkit==12.8.1
#  + cuda-toolkit==13.0.2
#  - einops==0.8.2
#  + einops==0.8.1
#  - filelock==3.29.7
#  + filelock==3.32.2
#  - fsspec==2025.3.0
#  + fsspec==2026.7.0
#  - gdown==5.2.2
#  + gdown==6.1.0
#  - greenlet==3.5.3
#  + greenlet==3.1.1
#  - hf-xet==1.5.1
#  + hf-xet==1.5.2
#  - huggingface-hub==1.23.0
#  + huggingface-hub==1.26.0
#  - imageio==2.37.3
#  + imageio==2.31.5
#  - joblib==1.5.3
#  + joblib==1.4.2
#  + mako==1.3.12
#  - matplotlib==3.10.0
#  + matplotlib==3.8.0
#  - numpy==2.0.2
#  + numpy==1.26.4
#  + numpyencoder==0.3.0
#  + nvidia-cublas==13.1.1.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.20.0.48
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.1
#  + nvidia-nccl-cu13==2.29.7
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  + optuna==4.2.1
#  - pandas==2.2.2
#  + pandas==2.2.3
#  - pillow==11.3.0
#  + pillow==12.3.0
#  - platformdirs==4.10.0
#  + platformdirs==4.11.0
#  - protobuf==5.29.6
#  + protobuf==7.35.1
#  - psutil==5.9.5
#  + psutil==7.2.2
#  - pytz==2025.2
#  + pytz==2026.3.post1
#  - requests==2.32.4
#  + requests==2.34.2
#  - scipy==1.16.3
#  + scipy==1.17.1
#  - sentry-sdk==2.65.0
#  + sentry-sdk==2.66.1
#  - setuptools==75.2.0
#  + setuptools==75.8.0
#  + smplx==0.1.28
#  - soupsieve==2.8.4
#  + soupsieve==2.9.1
#  - timm==1.0.28
#  + timm==1.0.15
#  - torch==2.11.0+cu128
#  + torch==2.12.1
#  + torch-dct==0.1.6
#  + torch-geometric==2.8.0.post1
#  - torchvision==0.26.0+cu128
#  + torchvision==0.27.1
#  - tqdm==4.67.3
#  + tqdm==4.66.1
#  + trimesh==4.6.8
#  - triton==3.6.0
#  + triton==3.7.1
#  - urllib3==2.5.0
#  + urllib3==2.7.0
#  - wandb==0.28.0
#  + wandb==0.28.1
#  - yarl==1.24.2
#  + yarl==1.24.5

# %%
drive.mount('/content/drive')
# !python -m thesis.src.run_pipeline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Initializing Unified Pipeline on: CUDA
#
# TRAIN SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 547 / 781                  |      3,876
#   Class 1    | 445 / 635                  |      4,878
#   Class 2    | 172 / 245                  |      2,934
#   Class 3    | 3 / 5                      |         33
# -----------------------------------------------------------------
#  TOTAL      | 1167 / 1666                |     11,721
#   * Filtered out 590 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# EVAL SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 78 / 781                   |        630
#   Class 1    | 63 / 635                   |        876
#   Class 2    | 24 / 245                   |        463
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 166 / 1666                 |      1,979
#   * Filtered out 591 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# TEST SET
#  Severity   | Sequences (Split / Total)  | Valid Chunks
# -----------------------------------------------------------------
#   Class 0    | 156 / 781                  |      1,289
#   Class 1    | 127 / 635                  |      1,401
#   Class 2    | 49 / 245                   |      1,107
#   Class 3    | 1 / 5                      |         10
# -----------------------------------------------------------------
#  TOTAL      | 333 / 1666                 |      3,807
#   * Filtered out 63 individual chunks with < 0.5m Z-travel.
#   * Excluded 30 entire sequence(s) from split pool (0 valid chunks >= 0.5m).
#   * Discarded 4 short sequence(s) (< 60 frames): ['062__062-15-006752_wid10_0', '004__004-13-005048_wid00_3', '004__004-13-007586_wid00_5', '037__037-15-009973_wid00_0']
#
# --- PHASE 1: TRAINING ---
# Training on device: cuda
# Epoch 0005/1000 | Train Loss: 0.009761
# Epoch 0010/1000 | Train Loss: 0.008818 | Eval MPJAE: 0.1478 rad
# Epoch 0015/1000 | Train Loss: 0.008227
# Epoch 0020/1000 | Train Loss: 0.007943 | Eval MPJAE: 0.1457 rad
# Epoch 0025/1000 | Train Loss: 0.007532
# Epoch 0030/1000 | Train Loss: 0.007486 | Eval MPJAE: 0.1402 rad
# Epoch 0035/1000 | Train Loss: 0.007179
# Epoch 0040/1000 | Train Loss: 0.007070 | Eval MPJAE: 0.1412 rad
# Epoch 0045/1000 | Train Loss: 0.006895
# Epoch 0050/1000 | Train Loss: 0.006867 | Eval MPJAE: 0.1398 rad
# Epoch 0055/1000 | Train Loss: 0.006602
# Epoch 0060/1000 | Train Loss: 0.006670 | Eval MPJAE: 0.1360 rad
# Epoch 0065/1000 | Train Loss: 0.006491
# Epoch 0070/1000 | Train Loss: 0.006548 | Eval MPJAE: 0.1422 rad
# Epoch 0075/1000 | Train Loss: 0.006510
# Epoch 0080/1000 | Train Loss: 0.006432 | Eval MPJAE: 0.1348 rad
# Epoch 0085/1000 | Train Loss: 0.006334
# Epoch 0090/1000 | Train Loss: 0.006221 | Eval MPJAE: 0.1382 rad
# Epoch 0095/1000 | Train Loss: 0.006264
# Epoch 0100/1000 | Train Loss: 0.006186 | Eval MPJAE: 0.1338 rad
# Epoch 0105/1000 | Train Loss: 0.006248
# Epoch 0110/1000 | Train Loss: 0.006102 | Eval MPJAE: 0.1365 rad
# Epoch 0115/1000 | Train Loss: 0.006139
# Epoch 0120/1000 | Train Loss: 0.005998 | Eval MPJAE: 0.1324 rad
# Epoch 0125/1000 | Train Loss: 0.006141
# Epoch 0130/1000 | Train Loss: 0.005990 | Eval MPJAE: 0.1321 rad
# Epoch 0135/1000 | Train Loss: 0.006010
# Epoch 0140/1000 | Train Loss: 0.005940 | Eval MPJAE: 0.1320 rad
# Epoch 0145/1000 | Train Loss: 0.006071
# Epoch 0150/1000 | Train Loss: 0.005934 | Eval MPJAE: 0.1316 rad
# Epoch 0155/1000 | Train Loss: 0.005920
# Epoch 0160/1000 | Train Loss: 0.005819 | Eval MPJAE: 0.1343 rad
# Epoch 0165/1000 | Train Loss: 0.006036
# Epoch 0170/1000 | Train Loss: 0.005872 | Eval MPJAE: 0.1323 rad
# Epoch 0175/1000 | Train Loss: 0.005827
# Epoch 0180/1000 | Train Loss: 0.005859 | Eval MPJAE: 0.1338 rad
# Epoch 0185/1000 | Train Loss: 0.005848
# Epoch 0190/1000 | Train Loss: 0.005898 | Eval MPJAE: 0.1324 rad
# Epoch 0195/1000 | Train Loss: 0.005758
# Epoch 0200/1000 | Train Loss: 0.005848 | Eval MPJAE: 0.1328 rad
# Epoch 0205/1000 | Train Loss: 0.005778
# Epoch 0210/1000 | Train Loss: 0.005894 | Eval MPJAE: 0.1349 rad
# Epoch 0215/1000 | Train Loss: 0.005736
# Epoch 0220/1000 | Train Loss: 0.005815 | Eval MPJAE: 0.1334 rad
# Epoch 0225/1000 | Train Loss: 0.005761
# Epoch 0230/1000 | Train Loss: 0.005765 | Eval MPJAE: 0.1369 rad
# Epoch 0235/1000 | Train Loss: 0.005672
# Epoch 0240/1000 | Train Loss: 0.005670 | Eval MPJAE: 0.1364 rad
# Epoch 0245/1000 | Train Loss: 0.005766
# Epoch 0250/1000 | Train Loss: 0.005699 | Eval MPJAE: 0.1298 rad
# Epoch 0255/1000 | Train Loss: 0.005635
# Epoch 0260/1000 | Train Loss: 0.005666 | Eval MPJAE: 0.1316 rad
# Epoch 0265/1000 | Train Loss: 0.005631
# Epoch 0270/1000 | Train Loss: 0.005739 | Eval MPJAE: 0.1407 rad
# Epoch 0275/1000 | Train Loss: 0.005618
# Epoch 0280/1000 | Train Loss: 0.005660 | Eval MPJAE: 0.1339 rad
# Epoch 0285/1000 | Train Loss: 0.005648
# Epoch 0290/1000 | Train Loss: 0.005642 | Eval MPJAE: 0.1371 rad
# Epoch 0295/1000 | Train Loss: 0.005700
# Epoch 0300/1000 | Train Loss: 0.005612 | Eval MPJAE: 0.1325 rad
# Epoch 0305/1000 | Train Loss: 0.005640
# Epoch 0310/1000 | Train Loss: 0.005559 | Eval MPJAE: 0.1326 rad
# Epoch 0315/1000 | Train Loss: 0.005577
# Epoch 0320/1000 | Train Loss: 0.005586 | Eval MPJAE: 0.1291 rad
# Epoch 0325/1000 | Train Loss: 0.005560
# Epoch 0330/1000 | Train Loss: 0.005518 | Eval MPJAE: 0.1297 rad
# Epoch 0335/1000 | Train Loss: 0.005726
# Epoch 0340/1000 | Train Loss: 0.005794 | Eval MPJAE: 0.1317 rad
# Epoch 0345/1000 | Train Loss: 0.005587
# Epoch 0350/1000 | Train Loss: 0.005572 | Eval MPJAE: 0.1306 rad
# Epoch 0355/1000 | Train Loss: 0.005664
# Epoch 0360/1000 | Train Loss: 0.005499 | Eval MPJAE: 0.1293 rad
# Epoch 0365/1000 | Train Loss: 0.005708
# Epoch 0370/1000 | Train Loss: 0.005553 | Eval MPJAE: 0.1350 rad
# Epoch 0375/1000 | Train Loss: 0.005540
# Epoch 0380/1000 | Train Loss: 0.005507 | Eval MPJAE: 0.1336 rad
# Epoch 0385/1000 | Train Loss: 0.005677
# Epoch 0390/1000 | Train Loss: 0.005597 | Eval MPJAE: 0.1292 rad
# Epoch 0395/1000 | Train Loss: 0.005627
# Epoch 0400/1000 | Train Loss: 0.005626 | Eval MPJAE: 0.1303 rad
# Epoch 0405/1000 | Train Loss: 0.005539
# Epoch 0410/1000 | Train Loss: 0.005524 | Eval MPJAE: 0.1313 rad
# Epoch 0415/1000 | Train Loss: 0.005622
# Epoch 0420/1000 | Train Loss: 0.005642 | Eval MPJAE: 0.1307 rad
# Epoch 0425/1000 | Train Loss: 0.005440
# Epoch 0430/1000 | Train Loss: 0.005553 | Eval MPJAE: 0.1300 rad
# Epoch 0435/1000 | Train Loss: 0.005424
# Epoch 0440/1000 | Train Loss: 0.005491 | Eval MPJAE: 0.1304 rad
# Epoch 0445/1000 | Train Loss: 0.005517
# Epoch 0450/1000 | Train Loss: 0.005464 | Eval MPJAE: 0.1290 rad
# Epoch 0455/1000 | Train Loss: 0.005543
# Epoch 0460/1000 | Train Loss: 0.005512 | Eval MPJAE: 0.1280 rad
# Epoch 0465/1000 | Train Loss: 0.005533
# Epoch 0470/1000 | Train Loss: 0.005471 | Eval MPJAE: 0.1291 rad
# Epoch 0475/1000 | Train Loss: 0.005413
# Epoch 0480/1000 | Train Loss: 0.005497 | Eval MPJAE: 0.1393 rad
# Epoch 0485/1000 | Train Loss: 0.005859
# Epoch 0490/1000 | Train Loss: 0.005488 | Eval MPJAE: 0.1303 rad
# Epoch 0495/1000 | Train Loss: 0.005436
# Epoch 0500/1000 | Train Loss: 0.005345 | Eval MPJAE: 0.1293 rad
# Epoch 0505/1000 | Train Loss: 0.005488
# Epoch 0510/1000 | Train Loss: 0.005616 | Eval MPJAE: 0.1322 rad
# Epoch 0515/1000 | Train Loss: 0.005659
# Epoch 0520/1000 | Train Loss: 0.005585 | Eval MPJAE: 0.1294 rad
# Epoch 0525/1000 | Train Loss: 0.005544
# Epoch 0530/1000 | Train Loss: 0.005519 | Eval MPJAE: 0.1330 rad
# Epoch 0535/1000 | Train Loss: 0.005588
# Epoch 0540/1000 | Train Loss: 0.005523 | Eval MPJAE: 0.1312 rad
# Epoch 0545/1000 | Train Loss: 0.005541
# Epoch 0550/1000 | Train Loss: 0.005555 | Eval MPJAE: 0.1304 rad
# Epoch 0555/1000 | Train Loss: 0.005527
# Epoch 0560/1000 | Train Loss: 0.005429 | Eval MPJAE: 0.1324 rad
# Epoch 0565/1000 | Train Loss: 0.005515
# Epoch 0570/1000 | Train Loss: 0.005479 | Eval MPJAE: 0.1311 rad
# Epoch 0575/1000 | Train Loss: 0.005528
# Epoch 0580/1000 | Train Loss: 0.005460 | Eval MPJAE: 0.1342 rad
# Epoch 0585/1000 | Train Loss: 0.005531
# Epoch 0590/1000 | Train Loss: 0.005533 | Eval MPJAE: 0.1291 rad
# Epoch 0595/1000 | Train Loss: 0.005409
# Epoch 0600/1000 | Train Loss: 0.005523 | Eval MPJAE: 0.1297 rad
# Epoch 0605/1000 | Train Loss: 0.005954
# Epoch 0610/1000 | Train Loss: 0.005632 | Eval MPJAE: 0.1311 rad
# Epoch 0615/1000 | Train Loss: 0.005607
# Epoch 0620/1000 | Train Loss: 0.005615 | Eval MPJAE: 0.1336 rad
# Epoch 0625/1000 | Train Loss: 0.005562
# Epoch 0630/1000 | Train Loss: 0.005576 | Eval MPJAE: 0.1310 rad
# Epoch 0635/1000 | Train Loss: 0.005580
# Epoch 0640/1000 | Train Loss: 0.005498 | Eval MPJAE: 0.1323 rad
# Epoch 0645/1000 | Train Loss: 0.005606
# Epoch 0650/1000 | Train Loss: 0.005560 | Eval MPJAE: 0.1349 rad
# Epoch 0655/1000 | Train Loss: 0.005498
# Epoch 0660/1000 | Train Loss: 0.005521 | Eval MPJAE: 0.1322 rad
# Epoch 0665/1000 | Train Loss: 0.005628
# Epoch 0670/1000 | Train Loss: 0.005530 | Eval MPJAE: 0.1326 rad
# Epoch 0675/1000 | Train Loss: 0.005558
# Epoch 0680/1000 | Train Loss: 0.005530 | Eval MPJAE: 0.1362 rad
# Epoch 0685/1000 | Train Loss: 0.005492
# Epoch 0690/1000 | Train Loss: 0.005520 | Eval MPJAE: 0.1308 rad
# Epoch 0695/1000 | Train Loss: 0.005560
# Epoch 0700/1000 | Train Loss: 0.005456 | Eval MPJAE: 0.1314 rad
# Epoch 0705/1000 | Train Loss: 0.005458
# Epoch 0710/1000 | Train Loss: 0.005412 | Eval MPJAE: 0.1358 rad
# Epoch 0715/1000 | Train Loss: 0.005521
# Epoch 0720/1000 | Train Loss: 0.005493 | Eval MPJAE: 0.1307 rad
# Epoch 0725/1000 | Train Loss: 0.005460
# Epoch 0730/1000 | Train Loss: 0.005361 | Eval MPJAE: 0.1333 rad
# Epoch 0735/1000 | Train Loss: 0.005513
# Epoch 0740/1000 | Train Loss: 0.005500 | Eval MPJAE: 0.1325 rad
# Epoch 0745/1000 | Train Loss: 0.005463
# Epoch 0750/1000 | Train Loss: 0.005465 | Eval MPJAE: 0.1325 rad
# Epoch 0755/1000 | Train Loss: 0.005508
# Epoch 0760/1000 | Train Loss: 0.005453 | Eval MPJAE: 0.1314 rad
# Epoch 0765/1000 | Train Loss: 0.005449
# Epoch 0770/1000 | Train Loss: 0.005366 | Eval MPJAE: 0.1307 rad
# Epoch 0775/1000 | Train Loss: 0.005346
# Epoch 0780/1000 | Train Loss: 0.005464 | Eval MPJAE: 0.1334 rad
# Epoch 0785/1000 | Train Loss: 0.005438
# Epoch 0790/1000 | Train Loss: 0.005352 | Eval MPJAE: 0.1319 rad
# Epoch 0795/1000 | Train Loss: 0.005400
# Epoch 0800/1000 | Train Loss: 0.005478 | Eval MPJAE: 0.1313 rad
# Epoch 0805/1000 | Train Loss: 0.005480
# Epoch 0810/1000 | Train Loss: 0.005395 | Eval MPJAE: 0.1331 rad
# Epoch 0815/1000 | Train Loss: 0.005501
# Epoch 0820/1000 | Train Loss: 0.005411 | Eval MPJAE: 0.1316 rad
# Epoch 0825/1000 | Train Loss: 0.005393
# Epoch 0830/1000 | Train Loss: 0.005401 | Eval MPJAE: 0.1336 rad
# Epoch 0835/1000 | Train Loss: 0.005472
# Epoch 0840/1000 | Train Loss: 0.005498 | Eval MPJAE: 0.1354 rad
# Epoch 0845/1000 | Train Loss: 0.005437
# Epoch 0850/1000 | Train Loss: 0.005383 | Eval MPJAE: 0.1329 rad
# Epoch 0855/1000 | Train Loss: 0.005469
# Epoch 0860/1000 | Train Loss: 0.005419 | Eval MPJAE: 0.1355 rad
# Epoch 0865/1000 | Train Loss: 0.005484
# Epoch 0870/1000 | Train Loss: 0.005430 | Eval MPJAE: 0.1345 rad
# Epoch 0875/1000 | Train Loss: 0.005359
# Epoch 0880/1000 | Train Loss: 0.005466 | Eval MPJAE: 0.1461 rad
# Epoch 0885/1000 | Train Loss: 0.005303
# Epoch 0890/1000 | Train Loss: 0.005472 | Eval MPJAE: 0.1327 rad
# Epoch 0895/1000 | Train Loss: 0.005395
# Epoch 0900/1000 | Train Loss: 0.005375 | Eval MPJAE: 0.1339 rad
# Epoch 0905/1000 | Train Loss: 0.005377
# Epoch 0910/1000 | Train Loss: 0.005348 | Eval MPJAE: 0.1336 rad
# Epoch 0915/1000 | Train Loss: 0.005362
# Epoch 0920/1000 | Train Loss: 0.005421 | Eval MPJAE: 0.1348 rad
# Epoch 0925/1000 | Train Loss: 0.005373
# Epoch 0930/1000 | Train Loss: 0.005373 | Eval MPJAE: 0.1350 rad
# Epoch 0935/1000 | Train Loss: 0.005432
# Epoch 0940/1000 | Train Loss: 0.005631 | Eval MPJAE: 0.1374 rad
# Epoch 0945/1000 | Train Loss: 0.005395
# Epoch 0950/1000 | Train Loss: 0.005501 | Eval MPJAE: 0.1323 rad
# Epoch 0955/1000 | Train Loss: 0.005470
# Epoch 0960/1000 | Train Loss: 0.005471 | Eval MPJAE: 0.1308 rad
# Epoch 0965/1000 | Train Loss: 0.005392
# Epoch 0970/1000 | Train Loss: 0.005390 | Eval MPJAE: 0.1337 rad
# Epoch 0975/1000 | Train Loss: 0.005439
# Epoch 0980/1000 | Train Loss: 0.005424 | Eval MPJAE: 0.1313 rad
# Epoch 0985/1000 | Train Loss: 0.005365
# Epoch 0990/1000 | Train Loss: 0.005398 | Eval MPJAE: 0.1312 rad
# Epoch 0995/1000 | Train Loss: 0.005374
# Epoch 1000/1000 | Train Loss: 0.005373 | Eval MPJAE: 0.1366 rad
#
# Training complete. Model saved to thesis/models/baseline_model_v2.pth
#
# --- PHASE 2: DATASET GENERATION ---
#
# --- PHASE 3: FORMAT CONVERSION ---
# Formatting and caching raw 6D sequences...
# Ground Truth H36M data already exists.
# Formatting Generated data to SMPL...
# Saved generated SMPL data to: thesis/data/processed/baseline_model_v2/SMPL/generated.pkl
# Converting Generated SMPL -> H36M...
# Input Data: thesis/data/processed/baseline_model_v2/SMPL/generated.pkl
# Output Dir: thesis/data/processed/baseline_model_v2/h36m
# /usr/local/lib/python3.12/dist-packages/chumpy/ch_ops.py:85: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   assert(order is 'C' or order is None)
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Converting generated to 3D World Coords:   0% 0/1 [00:00<?, ?it/s]
# Processing GEN:   0% 0/3807 [00:00<?, ?it/s]
# Processing GEN:   0% 13/3807 [00:00<00:30, 126.07it/s]
# Processing GEN:   1% 40/3807 [00:00<00:18, 205.51it/s]
# Processing GEN:   2% 67/3807 [00:00<00:16, 230.88it/s]
# Processing GEN:   2% 94/3807 [00:00<00:15, 243.06it/s]
# Processing GEN:   3% 121/3807 [00:00<00:14, 249.73it/s]
# Processing GEN:   4% 148/3807 [00:00<00:14, 253.92it/s]
# Processing GEN:   5% 175/3807 [00:00<00:14, 256.16it/s]
# Processing GEN:   5% 202/3807 [00:00<00:13, 257.64it/s]
# Processing GEN:   6% 229/3807 [00:00<00:13, 258.22it/s]
# Processing GEN:   7% 255/3807 [00:01<00:13, 258.39it/s]
# Processing GEN:   7% 281/3807 [00:01<00:13, 257.60it/s]
# Processing GEN:   8% 307/3807 [00:01<00:13, 257.30it/s]
# Processing GEN:   9% 333/3807 [00:01<00:13, 257.30it/s]
# Processing GEN:   9% 359/3807 [00:01<00:13, 257.62it/s]
# Processing GEN:  10% 385/3807 [00:01<00:13, 257.75it/s]
# Processing GEN:  11% 411/3807 [00:01<00:13, 257.31it/s]
# Processing GEN:  11% 437/3807 [00:01<00:13, 256.52it/s]
# Processing GEN:  12% 463/3807 [00:01<00:13, 257.01it/s]
# Processing GEN:  13% 489/3807 [00:01<00:12, 256.90it/s]
# Processing GEN:  14% 515/3807 [00:02<00:12, 257.26it/s]
# Processing GEN:  14% 541/3807 [00:02<00:12, 257.51it/s]
# Processing GEN:  15% 567/3807 [00:02<00:12, 257.57it/s]
# Processing GEN:  16% 593/3807 [00:02<00:12, 257.24it/s]
# Processing GEN:  16% 619/3807 [00:02<00:12, 256.64it/s]
# Processing GEN:  17% 645/3807 [00:02<00:12, 256.27it/s]
# Processing GEN:  18% 671/3807 [00:02<00:12, 256.53it/s]
# Processing GEN:  18% 697/3807 [00:02<00:12, 255.82it/s]
# Processing GEN:  19% 723/3807 [00:02<00:12, 256.41it/s]
# Processing GEN:  20% 749/3807 [00:02<00:11, 256.67it/s]
# Processing GEN:  20% 776/3807 [00:03<00:11, 257.81it/s]
# Processing GEN:  21% 802/3807 [00:03<00:11, 257.97it/s]
# Processing GEN:  22% 828/3807 [00:03<00:11, 258.28it/s]
# Processing GEN:  22% 854/3807 [00:03<00:11, 258.65it/s]
# Processing GEN:  23% 881/3807 [00:03<00:11, 259.33it/s]
# Processing GEN:  24% 907/3807 [00:03<00:11, 258.69it/s]
# Processing GEN:  25% 933/3807 [00:03<00:11, 257.83it/s]
# Processing GEN:  25% 959/3807 [00:03<00:11, 257.34it/s]
# Processing GEN:  26% 985/3807 [00:03<00:10, 257.28it/s]
# Processing GEN:  27% 1011/3807 [00:03<00:10, 257.80it/s]
# Processing GEN:  27% 1037/3807 [00:04<00:10, 257.90it/s]
# Processing GEN:  28% 1063/3807 [00:04<00:10, 257.51it/s]
# Processing GEN:  29% 1089/3807 [00:04<00:10, 257.70it/s]
# Processing GEN:  29% 1115/3807 [00:04<00:10, 257.76it/s]
# Processing GEN:  30% 1141/3807 [00:04<00:10, 257.78it/s]
# Processing GEN:  31% 1167/3807 [00:04<00:10, 258.19it/s]
# Processing GEN:  31% 1194/3807 [00:04<00:10, 258.78it/s]
# Processing GEN:  32% 1220/3807 [00:04<00:10, 258.57it/s]
# Processing GEN:  33% 1246/3807 [00:04<00:09, 258.09it/s]
# Processing GEN:  33% 1272/3807 [00:04<00:09, 257.82it/s]
# Processing GEN:  34% 1298/3807 [00:05<00:09, 257.72it/s]
# Processing GEN:  35% 1324/3807 [00:05<00:09, 257.37it/s]
# Processing GEN:  35% 1350/3807 [00:05<00:09, 256.87it/s]
# Processing GEN:  36% 1376/3807 [00:05<00:09, 256.78it/s]
# Processing GEN:  37% 1402/3807 [00:05<00:09, 255.69it/s]
# Processing GEN:  38% 1428/3807 [00:05<00:09, 253.98it/s]
# Processing GEN:  38% 1454/3807 [00:05<00:09, 250.70it/s]
# Processing GEN:  39% 1480/3807 [00:05<00:09, 252.84it/s]
# Processing GEN:  40% 1506/3807 [00:05<00:09, 254.85it/s]
# Processing GEN:  40% 1532/3807 [00:06<00:08, 254.75it/s]
# Processing GEN:  41% 1558/3807 [00:06<00:08, 251.46it/s]
# Processing GEN:  42% 1584/3807 [00:06<00:08, 253.48it/s]
# Processing GEN:  42% 1610/3807 [00:06<00:08, 253.40it/s]
# Processing GEN:  43% 1636/3807 [00:06<00:08, 253.43it/s]
# Processing GEN:  44% 1662/3807 [00:06<00:08, 253.32it/s]
# Processing GEN:  44% 1688/3807 [00:06<00:08, 253.44it/s]
# Processing GEN:  45% 1714/3807 [00:06<00:08, 253.47it/s]
# Processing GEN:  46% 1740/3807 [00:06<00:08, 253.38it/s]
# Processing GEN:  46% 1766/3807 [00:06<00:08, 253.26it/s]
# Processing GEN:  47% 1792/3807 [00:07<00:07, 252.44it/s]
# Processing GEN:  48% 1818/3807 [00:07<00:07, 253.14it/s]
# Processing GEN:  48% 1844/3807 [00:07<00:07, 254.07it/s]
# Processing GEN:  49% 1870/3807 [00:07<00:08, 233.54it/s]
# Processing GEN:  50% 1895/3807 [00:07<00:08, 236.00it/s]
# Processing GEN:  50% 1920/3807 [00:07<00:07, 237.78it/s]
# Processing GEN:  51% 1945/3807 [00:07<00:07, 241.17it/s]
# Processing GEN:  52% 1970/3807 [00:07<00:07, 238.16it/s]
# Processing GEN:  52% 1995/3807 [00:07<00:07, 240.76it/s]
# Processing GEN:  53% 2021/3807 [00:07<00:07, 244.26it/s]
# Processing GEN:  54% 2046/3807 [00:08<00:07, 244.00it/s]
# Processing GEN:  54% 2071/3807 [00:08<00:07, 242.58it/s]
# Processing GEN:  55% 2096/3807 [00:08<00:07, 240.72it/s]
# Processing GEN:  56% 2121/3807 [00:08<00:07, 240.69it/s]
# Processing GEN:  56% 2146/3807 [00:08<00:07, 235.98it/s]
# Processing GEN:  57% 2170/3807 [00:08<00:07, 233.61it/s]
# Processing GEN:  58% 2195/3807 [00:08<00:06, 236.83it/s]
# Processing GEN:  58% 2221/3807 [00:08<00:06, 241.77it/s]
# Processing GEN:  59% 2246/3807 [00:08<00:06, 232.19it/s]
# Processing GEN:  60% 2270/3807 [00:09<00:06, 230.62it/s]
# Processing GEN:  60% 2294/3807 [00:09<00:06, 217.95it/s]
# Processing GEN:  61% 2319/3807 [00:09<00:06, 226.66it/s]
# Processing GEN:  62% 2345/3807 [00:09<00:06, 234.33it/s]
# Processing GEN:  62% 2371/3807 [00:09<00:05, 239.43it/s]
# Processing GEN:  63% 2397/3807 [00:09<00:05, 243.84it/s]
# Processing GEN:  64% 2423/3807 [00:09<00:05, 246.57it/s]
# Processing GEN:  64% 2449/3807 [00:09<00:05, 249.25it/s]
# Processing GEN:  65% 2475/3807 [00:09<00:05, 250.83it/s]
# Processing GEN:  66% 2501/3807 [00:09<00:05, 251.81it/s]
# Processing GEN:  66% 2527/3807 [00:10<00:05, 252.24it/s]
# Processing GEN:  67% 2553/3807 [00:10<00:04, 252.64it/s]
# Processing GEN:  68% 2579/3807 [00:10<00:04, 253.02it/s]
# Processing GEN:  68% 2605/3807 [00:10<00:04, 253.42it/s]
# Processing GEN:  69% 2631/3807 [00:10<00:04, 253.81it/s]
# Processing GEN:  70% 2657/3807 [00:10<00:04, 253.80it/s]
# Processing GEN:  70% 2683/3807 [00:10<00:04, 252.96it/s]
# Processing GEN:  71% 2709/3807 [00:10<00:04, 251.70it/s]
# Processing GEN:  72% 2735/3807 [00:10<00:04, 251.98it/s]
# Processing GEN:  73% 2761/3807 [00:11<00:04, 252.19it/s]
# Processing GEN:  73% 2787/3807 [00:11<00:04, 252.33it/s]
# Processing GEN:  74% 2813/3807 [00:11<00:03, 251.97it/s]
# Processing GEN:  75% 2839/3807 [00:11<00:03, 251.87it/s]
# Processing GEN:  75% 2865/3807 [00:11<00:03, 251.67it/s]
# Processing GEN:  76% 2891/3807 [00:11<00:03, 251.24it/s]
# Processing GEN:  77% 2917/3807 [00:11<00:03, 250.88it/s]
# Processing GEN:  77% 2943/3807 [00:11<00:03, 250.66it/s]
# Processing GEN:  78% 2969/3807 [00:11<00:03, 251.22it/s]
# Processing GEN:  79% 2995/3807 [00:11<00:03, 249.78it/s]
# Processing GEN:  79% 3020/3807 [00:12<00:03, 249.78it/s]
# Processing GEN:  80% 3046/3807 [00:12<00:03, 250.53it/s]
# Processing GEN:  81% 3072/3807 [00:12<00:02, 252.31it/s]
# Processing GEN:  81% 3098/3807 [00:12<00:02, 252.81it/s]
# Processing GEN:  82% 3124/3807 [00:12<00:02, 253.14it/s]
# Processing GEN:  83% 3150/3807 [00:12<00:02, 253.23it/s]
# Processing GEN:  83% 3176/3807 [00:12<00:02, 253.51it/s]
# Processing GEN:  84% 3202/3807 [00:12<00:02, 252.48it/s]
# Processing GEN:  85% 3228/3807 [00:12<00:02, 252.93it/s]
# Processing GEN:  85% 3254/3807 [00:12<00:02, 253.37it/s]
# Processing GEN:  86% 3280/3807 [00:13<00:02, 253.59it/s]
# Processing GEN:  87% 3306/3807 [00:13<00:01, 253.87it/s]
# Processing GEN:  88% 3332/3807 [00:13<00:01, 254.51it/s]
# Processing GEN:  88% 3358/3807 [00:13<00:01, 254.99it/s]
# Processing GEN:  89% 3384/3807 [00:13<00:01, 255.55it/s]
# Processing GEN:  90% 3410/3807 [00:13<00:01, 255.77it/s]
# Processing GEN:  90% 3436/3807 [00:13<00:01, 256.24it/s]
# Processing GEN:  91% 3462/3807 [00:13<00:01, 254.17it/s]
# Processing GEN:  92% 3488/3807 [00:13<00:01, 252.26it/s]
# Processing GEN:  92% 3514/3807 [00:13<00:01, 251.60it/s]
# Processing GEN:  93% 3540/3807 [00:14<00:01, 252.16it/s]
# Processing GEN:  94% 3566/3807 [00:14<00:00, 252.42it/s]
# Processing GEN:  94% 3592/3807 [00:14<00:00, 251.77it/s]
# Processing GEN:  95% 3618/3807 [00:14<00:00, 251.24it/s]
# Processing GEN:  96% 3644/3807 [00:14<00:00, 252.21it/s]
# Processing GEN:  96% 3670/3807 [00:14<00:00, 251.93it/s]
# Processing GEN:  97% 3696/3807 [00:14<00:00, 251.75it/s]
# Processing GEN:  98% 3722/3807 [00:14<00:00, 251.89it/s]
# Processing GEN:  98% 3748/3807 [00:14<00:00, 253.19it/s]
# Processing GEN:  99% 3774/3807 [00:15<00:00, 254.12it/s]
# Processing GEN: 100% 3807/3807 [00:15<00:00, 251.18it/s]
# Converting generated to 3D World Coords: 100% 1/1 [00:15<00:00, 15.16s/it]
#
# --- PHASE 4: EVALUATION ---
#
# Processing dataset: thesis/data/processed/baseline_model_v2/h36m/ground_truth_3d_world.npz
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/baseline_model_v2/evaluation/gt_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/baseline_model_v2/h36m/gt_heel_strikes.json
#
# Processing dataset: thesis/data/processed/baseline_model_v2/h36m/generated_3d_world.npz
# [Evaluator] Saved evaluation distributions to: thesis/data/processed/baseline_model_v2/evaluation/gen_h36m_distributions.pkl
# [Evaluator] Saved heel strike detection data to: thesis/data/processed/baseline_model_v2/h36m/gen_heel_strikes.json
#
# --- SMPL SO(3) Evaluation ---
# Evaluated 3807 matching sequences.
#
# Overall Category Means (radians):
#   -> Overall             : 0.029009 rad
#   -> Lower Body          : 0.045279 rad
#   -> Upper Body          : 0.019247 rad
#   -> Hips                : 0.049432 rad
#   -> Knees               : 0.079304 rad
#   -> Ankles & Feet       : 0.030780 rad
#   -> Shoulders & Collars : 0.024767 rad
#   -> Left Body           : 0.032915 rad
#   -> Right Body          : 0.032809 rad
#
# Saved detailed MPJAE evaluation results to: thesis/data/processed/baseline_model_v2/evaluation/smpl_mpjae_evaluation.json
#
# Pipeline Finished Successfully!
